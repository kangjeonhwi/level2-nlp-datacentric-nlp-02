# %%
import os
import random
import numpy as np
import pandas as pd
from tqdm import tqdm

import torch
from torch.utils.data import Dataset

import evaluate
from transformers import AutoModelForSequenceClassification, AutoTokenizer
from transformers import DataCollatorWithPadding
from transformers import TrainingArguments, Trainer

from sklearn.model_selection import train_test_split

SEED = 456
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)

DEVICE = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
DEVICE
# Out:
# device(type='cuda')

# %%
BASE_DIR = os.getcwd()
DATA_DIR = os.path.join(BASE_DIR, 'data')
OUTPUT_DIR = os.path.join(DATA_DIR, 'outputs')

model_name = "klue/roberta-large"

# %% [markdown]
# # Load Datasets

# %%
original_path = os.path.join(DATA_DIR, 'train.csv')
original_df = pd.read_csv(original_path)
original_df.head()
# Out:
#                     ID                              text  target
# 0  ynat-v1_train_00000  정i :파1 미사z KT( 이용기간 2e 단] Q분종U2보       4
# 1  ynat-v1_train_00001       K찰.국DLwo 로L3한N% 회장 2 T0&}송=       3
# 2  ynat-v1_train_00002            m 김정) 자주통일 새,?r열1나가야1보       2
# 3  ynat-v1_train_00003     갤노트8 주말 27만대 개통…시장은 불법 보조금 얼룩       5
# 4  ynat-v1_train_00004      pI美대선I앞두고 R2fr단 발] $비해 감시 강화       6

# %%
noised_path = os.path.join(DATA_DIR, 'kjs/noisy_df.csv')
noised_df = pd.read_csv(noised_path)
noised_df
# Out:
#                        ID                              text  target
# 0     ynat-v1_train_00000  정i :파1 미사z KT( 이용기간 2e 단] Q분종U2보       4
# 1     ynat-v1_train_00001       K찰.국DLwo 로L3한N% 회장 2 T0&}송=       3
# 2     ynat-v1_train_00002            m 김정) 자주통일 새,?r열1나가야1보       2
# 3     ynat-v1_train_00004      pI美대선I앞두고 R2fr단 발] $비해 감시 강화       6
# 4     ynat-v1_train_00006             프로야구~롯TKIAs광주 경기 y천취소       1
# ...                   ...                               ...     ...
# 1594  ynat-v1_train_02787   13이 노바 라이n2·미J어패0 T3 10 결G상품% *       6
# 1595  ynat-v1_train_02788                남원소식 춘>X학%단+장Rn 모집       0
# 1596  ynat-v1_train_02789       이총리,세4. H직 완fl지 못해E할 일 꽤;남아       2
# 1597  ynat-v1_train_02792       높`X#E율…}BO Q"[/선수 몸값 상승 CAO       1
# 1598  ynat-v1_train_02797  텔레그램+한D 등h亞서 2시간H다운…C버T정gf39종!2보       4
#
# [1599 rows x 3 columns]

# %%
cleaned_path = os.path.join(DATA_DIR, 'fill_mask/train_generated.csv')
cleaned_df = pd.read_csv(cleaned_path)
cleaned_df.head()
# Out:
#                     ID                                           text  target
# 0  ynat-v1_train_00000               정권이 파리 미사 참석에 이용기간 제한을 두고 분열을 보임       4
# 1  ynat-v1_train_00001                          찰 국 로한 회장이 맡은 주요 프로젝트       3
# 2  ynat-v1_train_00002                    "김정은, 자주통일 새 열쇠를 잡고 나서야 한다"       2
# 3  ynat-v1_train_00003   "갤럭시 노트 7, 주말 동안 10만 대 개통…시장 불법 보조금 논란에 얼룩져"       5
# 4  ynat-v1_train_00004                        "대선을 앞두고 감시 강화, 단발적 비해"       6

# %%
augmented_path = os.path.join(DATA_DIR, 'fill_mask/train_filled.csv')
augmented_df = pd.read_csv(augmented_path)
augmented_df
# Out:
#                        ID                                     text  target
# 0     ynat-v1_train_00000               한국 축구 대표팀, 월드컵 예선전서 3-1 승리       4
# 1     ynat-v1_train_00001           중국, 코로나19 백신 개발 성공 및 안전성 검증 완료       3
# 2     ynat-v1_train_00002                   정부, 올해 경제 성장률 3% 예상 발표       2
# 3     ynat-v1_train_00003          갤노트 주말 100만 대 개통, 시장은 불법 보조금 얼룩       5
# 4     ynat-v1_train_00004                대선 앞두고 1억 5천만 원 추가로 감시 강화       6
# ...                   ...                                      ...     ...
# 2795  ynat-v1_train_02795          트럼프 폭스뉴스 앵커들 충성도 점수 매겨 점만점에 50점       6
# 2796  ynat-v1_train_02796            삼성 갤럭시 S22 정식 출시 첫 주말 이통시장 침묵       2
# 2797  ynat-v1_train_02797            텔레그램, 한 시간 동안 서비스 중단 및 정상화 과정       4
# 2798  ynat-v1_train_02798   인터뷰 류현진, 친구에게 안타 맞는 것 싫어해 승부는 냉정한 것 같다       1
# 2799  ynat-v1_train_02799           지능정보사회 대비 국가 종합대책 마련 및 시행계획 발표       4
#
# [2800 rows x 3 columns]

# %%
self_train_path = os.path.join(DATA_DIR, 'Self_train/self_train_step2.csv')
self_train_df = pd.read_csv(self_train_path)
self_train_df
# Out:
#                        ID                               text  target
# 0     ynat-v1_train_00000              KT 이용기간 2분 종료될 예정입니다.       4
# 1     ynat-v1_train_00001   K찰국대통령이 로L한 회장에게 2시간 동안 면담을 요청했다       3
# 2     ynat-v1_train_00002                김정은, 자주통일 새해 메시지 발표       2
# 3     ynat-v1_train_00003      갤노트8 주말 27만대 개통…시장은 불법 보조금 얼룩       4
# 4     ynat-v1_train_00004          미 대선 앞두고 R2F 단 발 비해 감시 강화       6
# ...                   ...                                ...     ...
# 2795  ynat-v1_train_02795  트럼프 폭스뉴스 앵커들 충성도 점수매겨…10점만점에 12점도       6
# 2796  ynat-v1_train_02796        삼성 갤럭시S9 정식 출시 첫 주말 이통시장 잠잠       4
# 2797  ynat-v1_train_02797        텔레그램, 중국 서버에서 2시간 동안 서비스 중단       4
# 2798  ynat-v1_train_02798    인터뷰 류현진 친구에게 안타 맞는 것 싫어해…승부는 냉정       1
# 2799  ynat-v1_train_02799               지능정보사회 대비 국가 종합대책 마련       4
#
# [2800 rows x 3 columns]

# %% [markdown]
# # Make Train dataset

# %%
## 문자열 앞뒤 따옴표 제거
import re
def remove_outer_quotes(input_string):
    if type(input_string) == float :
        return ' '
    # 문자열의 앞뒤 공백을 제거
    cleaned = input_string.strip()
    
    # 작은따옴표와 큰따옴표 확인
    while cleaned.startswith('"') or cleaned.startswith("'"):
        cleaned = cleaned[1:]
    while cleaned.endswith('"') or cleaned.endswith("'"):
        cleaned = cleaned[:-1]
    
    return cleaned

# 테스트
example_string = '""코로나19 대면 수업, 원격 수업 대비 뚜렷한 선호도 드러나"""'
result = remove_outer_quotes(example_string)
print(result)
# Out:
# 코로나19 대면 수업, 원격 수업 대비 뚜렷한 선호도 드러나

# %%
## Cleaning noised data -> Label은 정상
denoising_df = self_train_df.copy()

for index, row in noised_df.iterrows():
    sample_id = row['ID']
    new_text = cleaned_df.loc[cleaned_df['ID'] == sample_id]['text'].values[0]
    new_text = remove_outer_quotes(new_text)
    
    if len(new_text) < 5 :
        denoising_df.drop(denoising_df[denoising_df['ID'] == sample_id].index, inplace=True)
    else :
        denoising_df.loc[denoising_df['ID'] == sample_id, 'text'] = new_text

denoising_df
# Out:
#                        ID                               text  target
# 0     ynat-v1_train_00000   정권이 파리 미사 참석에 이용기간 제한을 두고 분열을 보임       4
# 1     ynat-v1_train_00001              찰 국 로한 회장이 맡은 주요 프로젝트       3
# 2     ynat-v1_train_00002          김정은, 자주통일 새 열쇠를 잡고 나서야 한다       2
# 3     ynat-v1_train_00003      갤노트8 주말 27만대 개통…시장은 불법 보조금 얼룩       4
# 4     ynat-v1_train_00004              대선을 앞두고 감시 강화, 단발적 비해       6
# ...                   ...                                ...     ...
# 2795  ynat-v1_train_02795  트럼프 폭스뉴스 앵커들 충성도 점수매겨…10점만점에 12점도       6
# 2796  ynat-v1_train_02796        삼성 갤럭시S9 정식 출시 첫 주말 이통시장 잠잠       4
# 2797  ynat-v1_train_02797      텔레그램 서버, 한 시간 동안 다운, 보안 우려 제기       4
# 2798  ynat-v1_train_02798    인터뷰 류현진 친구에게 안타 맞는 것 싫어해…승부는 냉정       1
# 2799  ynat-v1_train_02799               지능정보사회 대비 국가 종합대책 마련       4
#
# [2764 rows x 3 columns]

# %%
## 데이터에서 불필요한 text row drop
denoising_df = denoising_df[denoising_df['text'].str.len() > 5]
denoising_df.to_csv(f'./data/Self_train/self_train_step2_cleaned.csv', index=False)

# %%
## 미리 학습했던 model을 이용해 re-labeling (Step 2)
model = AutoModelForSequenceClassification.from_pretrained(OUTPUT_DIR+"/self_train_step1/checkpoint-350").to(DEVICE)
tokenizer = AutoTokenizer.from_pretrained(model_name)
model.eval()

new_train = origin_train.copy()

for idx, sample in tqdm(origin_train.iterrows(), total=len(origin_train), desc="Evaluating"):
    target_id = sample['ID']

    if target_id in ids :
        continue

    inputs = tokenizer(sample['text'], return_tensors="pt").to(DEVICE)
    with torch.no_grad():
        logits = model(**inputs).logits
        pred = torch.argmax(torch.nn.Softmax(dim=1)(logits), dim=1).cpu().numpy()
        new_train.loc[new_train['ID'] == target_id, 'target'] = pred[0]

new_train.to_csv(f'./data/Self_train/self_train_step2.csv', index=False)

# %% [markdown]
# # DATA Augmentation with BM25

# %%
from rank_bm25 import BM25Okapi
import numpy as np
corpus = denoising_df['text'].values.tolist()
corpus = [sentence for sentence in corpus if len(sentence) > 5]
len(corpus)
# Out:
# 2764

# %%
# Hugging Face tokenizer 로드 (예: BERT tokenizer)
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenized_corpus = [tokenizer.tokenize(doc) for doc in corpus]

# BM25 모델 생성
bm25 = BM25Okapi(tokenized_corpus)

# %%
# augmentation된 문장들
augmented_corpus = np.concatenate((augmented_df['text'].values, cleaned_df['text'].values))
augmented_sentences = augmented_corpus.tolist()
augmented_sentences = [sentence for sentence in augmented_sentences if (type(sentence)!=float and len(sentence) > 5)]
print(len(augmented_sentences))
augmented_sentences
# Out:
# 5514
# [' 한국 축구 대표팀, 월드컵 예선전서 3-1 승리',
#  ' 중국, 코로나19 백신 개발 성공 및 안전성 검증 완료',
#  ' 정부, 올해 경제 성장률 3% 예상 발표',
#  ' 갤노트 주말 100만 대 개통, 시장은 불법 보조금 얼룩',
#  ' 대선 앞두고 1억 5천만 원 추가로 감시 강화',
#  ' 정부, 코로나19 대유행에 대한 대응책 발표',
#  ' 프로야구 롯데 자이언츠 광주 경기, 천만 관객을 위한 취소',
#  ' 아가메즈, 득점 우리카드에 3골을 넣어 손해보험을 완파 위 굳',
#  ' 삼성, 갤럭시 S21의 새로운 기능과 혁신: 5G, 화면, 카메라 기술 개선',
#  ' 듀얼심 아이폰 하반기 출시설 솔솔, 알뜰폰',
#  ' 삼성전자, 스마트폰 판매량 급증... (문맥에 따라 최종 복구 결과를 작성해주세요)',
#  ' 정부, 개인소득세율 25% 인하 발표',
#  ' 국내 코로나19 확진자 급증, 정부의 대응책 발표',
#  ' 한국 경제 성장률 3.2%로 상승',
#  ' 전국 고등학교, 대학수학능력시험 응시생 9만 명 넘어',
#  ' 서울시, 3개 지역에 코로나19 백신 접종 시작',
#  '  공사업체 협박 사건에 연루된 언론인이 분쟁 해결 명목으로 돈을 받고 집행유예 판결을 받다',
#  ' 월세 전환에 따른 주거비 부담 증가, 작년 역대 최고치 2.5% 증가',
#  ' 정부, 코로나19 백신 접종 계획 발표',
#  '  페이스북의 인터넷 드론 아퀼라, 실물 첫 시험',
#  ' 한국 경제, 세계 최대 경제 강국으로의 도약 - 우리나라 경제가 세계 최고 수준에 도달했다고 국제 경제 전문가들은 말합니다. ',
#  ' 삼성, 갤럭시 S21 5G 출시 예정',
#  '  현 차량 임원급 직원 채용 확대 계획 발표',
#  ' 아시안게임에서 목소리를 높인 박항서 베트남, 일본을 이길 수 있을까?',
#  ' 서울에 다시 오존주의보, 도심 서북동북권 발령 종합',
#  ' "선 폭 현장 조사 결과 발표" ',
#  ' 레콤, 분기 영업익 5천억원 증가, 사상 최대치 기록',
#  '  생명보험 인증에 유럽의 대가들이 몰려든다',
#  ' 강 감독, 로축구연맹에 회부된 제명 사건 ',
#  ' 해외로밍 금폭탄, 동차단이 더 빨리 진다',
#  ' 세계 인무역협회 올  무역인  천  백  배출한',
#  ' 박항서, 매직 베트남 축구 대표팀을 쏟아붓습니다!',
#  ' 학용품 산업에 석면 사용 규정을 지키세요',
#  ' 안보리 대북결의안  2379호 이행보고서 제출한 나라  개 육박',
#  ' 게시판 - 코로나가 바꾼 일상: 대국민 영상 공모',
#  ' 크루즈 관광객용 반나절 부산 해안 트레킹 상품 개발',
#  ' 생산 인공광 에 기보다 에 활 적',
#  ' 마틴 우리카드, 한국 리그로 코치 복귀 선언 "좋아요"',
#  ' 씽큐, 일부터 예판 디스플레이: 회 무상교체 혜택 제공',
#  ' 후쿠시마 원전 사고 이후 피폭 노동자의 증언, 원전 은폐와 속임수의 진실이 밝혀집니다',
#  ' 다저스, 버츠 감독과 류현 담당 포수 최환을 환영합니다.',
#  ' 일 연 상 의장, 창조경제 논의',
#  ' 한국민족의 뿌리가 북방 천년 전 한반도서 자생적으로 형성된 것임을 밝혀냈다',
#  ' 산업생산 3분기 고 제조 가동률은 금융위 수 합 보',
#  ' 유엔 의료 지원 사표 특별 제정, 흔들리는 국제 협력',
#  ' 자금 농업은행, 삼 명 직원 해고',
#  ' 김종 박사, 리먼 브러더스 사태처럼 충격 지속될 것',
#  ' 자 구 김정 트로 보니 도 모르 이',
#  ' 인국공 태 1년 무 공 고 진보인가',
#  ' 여성 비율 계속 증가: 입생 중 학생들의 9명 중 5명이 여성',
#  ' 근육조직 생성에 필수적인 열쇠 발견',
#  ' 위클 스 플코리아, 한국에서 얼마나 벌을 받았을까요?',
#  ' 코로나 19 대 등교 모습 변화',
#  ' "사진 찍기, 즐거운 시간 보내다: 개 카메라를 활용해보세요!"',
#  ' 스마트폰 실막 스마트폰 전자파 방해',
#  ' 유엔 리비아 내전 악화, 국제적 확산 우려, 아랍연맹 긴급회의 종합',
#  ' 문대통령, 김정택 전 프레지던트 트럼프와 조속히 끝내고 다짐',
#  ' 한미, 유전자 치료제 개발 협력 본격화',
#  ' 아사 트 프 외교 험 없다고 오바 도 였다',
#  ' 공룡과 파충류보다는 타조 매 등 새에 가깝다',
#  ' 대한항공 우리카드 꺾고 연승 칼텍스 라운드 전승 종합',
#  ' 자전거 도둑, 만 명의 피해자',
#  ' 나경원 원내대표, 영상 선출부터 퇴장까지 파란만장한 첫 1년',
#  ' 유라 아 경 연합 회 상품 교환 합의',
#  ' 부 리수 국제사회 임원들은 기꺼이 참여할 것이라는데 기대감 높아',
#  ' 챔피언스리그 강력한 마드리드 더비, 레알 마드리드와 아틀레티코 마드리드의 대결이 성사된다! ',
#  ' "콩 면금 나트륨 함량 높고 지질 함량 낮은 식물성 기름"',
#  ' "류현진, 전설의 투수에게 듣는다: 류현진 특집 다큐멘터리"',
#  ' "선 울 경 활성화 고용안 소 합"',
#  ' 모바일 컴퓨팅 미래는 서울서 국제학회 모비시스 개막',
#  ' 영상에서 냄새가 나는 수상한 차량을 퇴근길에 발견해 차량을 추격했습니다.',
#  ' 이스라엘 테러, 팔레스타인인 강연 차단, 비자도 취소',
#  ' 대한항공, 인천-바르셀로나 노선 첫 취항',
#  ' 월드 챔피언십에서 천재 감독 시코 오가 이끄는 한국팀의 활약, 한국전 승리',
#  ' 특허 호에 모 금 조달에 신고가',
#  ' "일리산 법정 내 처리 요"',
#  ' 대구 경북 고용유지지원금 신청 폭주 월  천 건 증가',
#  ' 본 카 애스턴마틴, 국내 대량 생산 시작',
#  ' 태블릿 조작설 변희재, 심 징역 년 처벌받아 악의적 공격 반복 종합',
#  ' 한산한 성산일출봉 주차장, 10월 5일 개장',
#  ' "추신수, 시애틀 마리너스 첫 경기에서.300 타율 기록" ',
#  ' 유영준 왕웨이, 조심스럽게 중국 내 투자 계획을 구상합니다. ',
#  ' 한국사이버 제1분기 영업이익 원  감소',
#  ' 네이버 모바일 연예판에도 콘텐츠 추천 시스템 적용',
#  ' 리비 신분 변 허용 의료 서로 사전 입 해야',
#  ' 수능 원서 접기 기한이 꽃피었습니다.',
#  ' 증시신상품 국채선물 인버스 ETF 종가',
#  ' 내비게이션, 국민의 관심을 끌다',
#  ' 서울문고, 풍그에 인수… 라인서점, 교영풍 양강도로 확장',
#  ' 온 으 한방 바 를 느끼다 천 한방 스',
#  ' 전 세계 최대 규모의 체험 관람차 개장',
#  ' 문대통령 호주 총리와 축구 평가전, 무승부 축하',
#  ' 멀티골  순형  로축구  그   운드',
#  ' 흥국운용, 천억원 규모의 중순위 인수금융펀드 출시 완료',
#  ' 구글, 픽셀 스마트폰 출시 없이 4분기 시장 점유율 상승',
#  ' 종이 면어도 삼중공 델로 설 증받는다',
#  ' 올 상반기 외 경제 자 역 증가',
#  ' 무수단 발사 대기권 재진입 기술 확보 여부가 관건',
#  ' 서방 국가에 백두산 연구 협력을 먼저 제안하며 과학외교 활발화',
#  ' 학농구 리그, 일 고려대 중앙대 경 개막',
#  ' 코스피, 미국발 악재에 또 급락 대로 털썩',
#  ' 도서관 대출 교육 목적 허용',
#  ' 승리에도 침통했던 박기원 감독 엔진을 끈 것 같다',
#  ' 한국관광공사, 중국 관광업계와 업무 협약 체결',
#  ' 프로축구 부천 FC와 안산 그리너스 FC가 무승부를 기록했습니다. ',
#  ' 프랑스 마을의 이',
#  ' 속 지역 도시 난개발 방 개정안 발의 놓',
#  ' 독 멈 선 데 수 원대 면 점 인 도 무산',
#  ' 럼 광합성 공장, 개발 착수',
#  ' 세아트 드라이빙 시뮬레이터 게임 출시',
#  ' 코로나19',
#  " 신간 '끗' 이자 법 코뮤니티",
#  ' 땅 파 코 나 격리시설 탈출한 외국인 청소부',
#  ' 최병륜 울산 지역 사장 체포',
#  ' 전광인 없이 한국전 컵에서 현 캐피탈을 격파한 종합 승리',
#  ' 어촌으로 봄 여행 떠나볼까? 해수부 체험 마을 10곳 추천',
#  ' 러시아 우주로켓이 벼락을 맞고도 무사히 탑재 위성을 정상 궤도에 올렸다. ',
#  ' 인터넷신문위원회, 게시판 관련 언론분쟁 대처 교육 실시',
#  ' 령 각한 균 조짐 동요 가 종합',
#  ' 손경산업, 한국조선해양과 협력방안 논의',
#  ' 대통령, 시도 일 리 언 지 이 고용 주역을 종합합니다',
#  ' 조 우 선동의 독 과 께 전 고',
#  ' 발언하 박광호, 전 국회의원 "국민의힘에 입당" 발표',
#  ' 자배구 대 팀 코 진 구성 완료 - 트너에 정기혁 감독',
#  ' 날씨 미 먼지 보통 수 오후부터 지고 곳곳에 일찍',
#  ' 선두 도 공사 칼텍 현 탈 연승 합',
#  ' 수산물 가격이 급격히 상승하자, 정부는 수산물 생산 확대를 위해 어업 당국에 각별한 주의를 기울이라고 지시했습니다.',
#  ' "2022년도 제1회 외환투자정책협의회 개최" ',
#  ' "애플, 아이폰 13 시리즈 출시 이벤트 개최"',
#  ' "모멘트 학교 급식 칸막이 폭파" ',
#  ' 올해 상반기 국내 소고기 생산량은 5억 6천만 kg에 달합니다. ',
#  ' "씨앤비 2022년 업무보고"',
#  ' 코오롱플라스틱, 분기 연결 영업익 3,000억 원 달성',
#  ' 대 화산 폭발로',
#  ' 리  엔 예비후 사전여론조사 결과 유출 논쟁',
#  ' 올해의 연극 베스트 3위: 옥상 밭 고추 - 왜 재공연인가? ',
#  ' 삼성 빅스, 개발자 데모 행사 첫 번째로 서울에서 개최',
#  ' 스마트폰 액세서리 업그레이드: 떼고 붙여보세요',
#  ' 무등산에서 광주지역 올해 첫 얼음 관찰',
#  ' 알림톡 무단 송출 카드 징계',
#  ' 대통령, 국회의원과 함께 사드 민심 청취 분 면담',
#  ' 지소미아 종료까지 일 남은  압박 속 고민 깊어지는 대통령',
#  ' 호텔에서 스타 셰프의 음식을 맛볼 수 있는 더플라자 레스토랑이 오픈합니다! ',
#  ' 우리은행 박혜진, 연봉 억원으로 연속 4년 연봉 퀸',
#  ' 친박 원내 표 보 유 단 화 홍문 도 종합',
#  ' 도자기 작품 상 수상자들 발표 ',
#  ' 시리보다 내가 낫다 빅스비의 세로드립 도발종합',
#  ' 분당 지역 대 대립 심화',
#  ' 월 소비자 지갑을 열어라 - 유통업계 할인 경쟁 격화',
#  ' 한국형 발사체 엔진 첫 연소시험 성공',
#  ' 김정은, 산시 향 향토문화 체험',
#  ' "힐만 감독, 산체스 일 불펜에서 대기"',
#  ' 반기 전, 여 2년 보(반기 전 2년 보)                ',
#  ' 수협, 공공주택 보증금 보험 가입률 100% 달성',
#  ' 칼텍스, 기업은행과 세터 이나연 이고은 트레이드 협력',
#  ' 사법부 판결 불확실성',
#  ' 최고 원중 의원, 에 대한 교안',
#  ' 지방 자치단체 정착민 투자 실태 조사',
#  ' 안랩, 통합 정보보안 서비스 개발 업무협약 체결',
#  ' 카 트 온라인, 한국항공우주연구원과 함께 교육 개강좌 공동 개설',
#  ' 당대회 나흘만에 일부 외신 취재 허용, 김정은 위원장 취임 발표',
#  ' 그픽 서울의 일강이, 서울에서 개최되는 국제 IT 행사입니다.',
#  ' 도쿄 주택가 공원 연못서 30대 여성이 토막난 시신으로 발견됨',
#  ' 홍콩 시위 참여 여성 경찰서에서 알몸 수색 강요당해',
#  ' 삼성, 세계 최초 후면 쿼드카메라 탑재 갤럭시 S20 공개',
#  ' 손흥민, 대표팀 합류 시점은 일 소집 참가 어려워',
#  ' 말 여행 의료용 딧짓 반입 금지',
#  ' 사채거래 행 조원 대비 증가',
#  ' 이트삭, 이 달에 2천만 달러를 들여 신규 사업장을 오픈합니다.',
#  ' 이란 상대 국적 체포 갈등, 구금 중 학대, 서로 비방',
#  ' 미네소타 람스, 홈 오픈 경기에서 2명 부상',
#  ' 홍남기 미래산업부 차관, 서울혁신센터 등 방문',
#  ' 페이오, 중동서 국 동 구 이란 고 강 종 발표',
#  ' 북한 사이버 공격 집단, 세계 은행들 대상  천억 원 탈취',
#  ' "발사체에 대한 미일 당국자 통화: 한미일 협력 확인"',
#  ' 명예로운 옮겨 쓰기 즐거움, 필사본의 문학적 가치',
#  ' 한·파, 동반성장 협약 체결',
#  ' 한국 아 명 키  일본 의 이 기 연극',
#  ' 러시아 타사 고객 대상 럭셔리 호텔 단지',
#  ' 삼성, 투자로 미래 먹거리 창출한다',
#  ' 포천아트밸리서 높이 절벽 배경 야간 공중쇼 개최',
#  ' 탈북민 착한봉사단, 연천서 통일염원 벽화 그린다',
#  ' 프로농구 울산 현대 모비스 피버스, 교체 선수 리엄스 영 영입',
#  ' 금융발전심의회 전체회의 개최',
#  ' 증권 농심, 분기 라면 부문 실적 개선 목표주가 상향 조정',
#  ' 반기문 유엔 사무총장이 관저에 리창 부부를 초대 만찬, 2년전 약속 지켜',
#  ' 새누리 원내대표, 화요일 여소야대 계파 회의 진행',
#  ' 100년 전 일본 건너간 조선 첫 여성 도공 백파선',
#  ' 등산 수업 확장, 경로 다양화',
#  ' "다저스, 4년 연속 NL MVP 수상 가능성 높지만, 우승은 아직 미지수"',
#  ' 뚝 떨어지는 출렁다리, 도로 위로 떨어져',
#  ' 구글, 세대 크롬캐스트 출시 신세계아이앤씨 단독 판매종합',
#  ' 서울자유시민대학 초대 학장에 정재권 전 한겨레신문 논설위원 임명',
#  ' 웨이포트, 월요일 상장폐지 신청 예정',
#  ' 강 대 발 알 리 뮌헨 맞: 한국과 독일의 축구 경기',
#  ' 남북정상회담 준비가 완료되었습니다. 남북 리허설, 또 리허설.',
#  ' 버닝썬 게이트를 다룬 그것이 알고 싶다',
#  ' 현대차 현대차증권, 1억 5,000만원에 매수',
#  ' 갤럭시 S21 부터 S21+ 까지, 환불만원 도서',
#  ' "나 혼자 산다" 시청률 상승',
#  ' 우증권 오리 중 성장 둔 목표가',
#  ' "립 공공 도서관이 독자 집중 명패를 새롭게 한다"',
#  ' 이 크 리아 친이 시설 격리 에 경쟁력 향상',
#  ' 문중원 기수 대책위, 정부가 나서라 인근까지 상여 행진',
#  ' "새누리당 갈등 폭발, 전국위원회는 어떤 결정을 내릴 것인가?"',
#  ' 몽니 두 선 트 동참 당 압',
#  ' 인 진군: 오전 7시에 시작된 주 보 해',
#  ' 한국 남자농구, 월드컵 아시아 예선서 중국을 제압하며 승전보를 올렸다',
#  ' 안철수, 장애인 정책 발표',
#  ' 아시안게임 키르기스스탄전 앞둔 김학범, 스스로 만든 가',
#  ' 은 문 적  양 풍 했 맹 이   문 행',
#  ' 폭포 야외로 전시된 시민들의 화관 인기',
#  ' 고지서 반정시에 사주한',
#  ' "선 장 남자 배 올 출전 충 히 가능하다"',
#  ' "소방서 화재, ',
#  ' "여자부 라운 브라질 미 과 대"',
#  ' 삼성, 분기 세계 스마트폰 점유율 1위를 지켰다… 중국의 맹추격에도 불구하고',
#  ' 경상도 시 오전 7시 대설주의보 발령',
#  ' 네덜란드 정부, 보스니아 무슬림 학살 사건에 대한 책임 인정',
#  ' 카카오미니 예판 30분 만에 마감, 접',
#  ' 민주당, 누리과정 예산 확보 대신 법인세 양보 모색',
#  ' "점박이 고양이 크게 더니 온 몸에 쥐났어요"',
#  ' 후랭코프, 두산에 승리하며 선착한 맹추격',
#  ' 청년 디지털 일자리 등  차 추경 사업 민간 채용률 겨우 1%에 불과하다.',
#  ' 미 로 사 상 호 화 돌입',
#  ' 보령시, 시간선택제 공무원  명 모집 공고',
#  ' 류현진, 랭킹 상승 막판 부진으로 온갖 의문 낳아',
#  ' "쉽게 열리지 않는, 메크론 골문"',
#  ' 충북 가마솥 더위 지속 주말에도 더워요',
#  ' "애플, 하반기 아이폰 13 예약 시작"',
#  ' 억만장자 베니 스타인메츠, 광산 뇌물 혐의로 기소되다',
#  ' 신간 답이 보이지 않는 상황을 견디는 힘: 한 부류의 사람들이 어떻게 극복하는가',
#  ' 길 조  파  외치    번  당 승부',
#  ' 출마금 10억 원의 슈 웡 홍 원, 투표해주세요',
#  ' 최희 헬비전 병사보다 연종합',
#  ' 이창민의 벼락같은 중거리포, 러시아 가는 길을 열어젖혔다',
#  ' 모바일 시큐리티 로드 돌파: 새로운 기술이 자동차 보안을 강화한다',
#  ' 배구 남녀 대표팀 임도헌, 라바리니 감독 보령서 짧은 상견례',
#  ' 자베스 여사, 정치권에 트럼프와의 타협을 촉구합니다',
#  ' 전기차가 맞먹는 양 전소',
#  " 명장 바비 콕스, 로맨틱 코미디 영화 '로맨틱 코미디'로 데뷔",
#  ' 공항 파키스탄 내 항공사 고조종사 교육 등',
#  ' 시판 코 아  페의 사상 최대 판매 기록',
#  ' 바르샤 이승우, 네 란드 팀으로 임대 가',
#  ' 대통령 후방테러 대비위한 러시아 방지법 제정',
#  ' 북미정상회담 성공을 위한 야당의 힘, 민주당 성사 앞에 서다',
#  ' 삼성, 애플, 구글 스마트폰 가을 대전 임박',
#  ' "트럼프 대통령, 이란의 드론 격추에 대한 보복 공격 승인을 돌연 철회하다" ',
#  ' 폴란드서 이란 겨냥  주도  여개국 중동문제회의 시작',
#  ' 네이버 인공지능, 식당 예약 전화 받는 콜 공개',
#  ' 봄비에 젖은 꽃망울',
#  ' "핑크퐁 영어 학습 앱, 출시" ',
#  ' "직언론인 조 족 장애인 시  폭  히는 시인"',
#  ' 초등학생들, 경북도청에 들러',
#  ' 인공지능 기술로 목소리 찾아드려요: 목소리 찾기 프로젝트',
#  ' 아이폰 13 프로 써보니 프로다운 카메라 성능 기대 이상',
#  ' 위 혁신, 출발 박물관, 발행 시작',
#  ' 국립민속박물관, 아카이브 만들기 특별전 개최',
#  ' 임도헌 감독, 젊은 선수들 자신감 얻었다… 내년 월드컵 진출 진짜 승부',
#  ' 대우조선해양, 4천억 원 규모의 운선 2척 수주 계약 체결',
#  ' 광년 떨어진 곳에서 지구 크기의 삼형제 발견',
#  ' 말과 여자의 주권 인류 무형 문화 유산이 화를 낸다. ',
#  ' 출신 왕웨이중, 복귀 에인절스전 이닝 무실점 무안타 무볼넷',
#  ' 그린피스, 리 결함 심각성 평가',
#  ' 차범근과 손흥민, 공통점과 아홉수 그리고 그들의 성공 스토리',
#  ' 신년사 손학규, 다당제 합의제로 희망 드리는 정치 실천',
#  ' 노벨평화상 수상자 발표에 아프리카 환호 각국 정상 환영 잇따라',
#  ' "가 전한 설 민심, 정권교체 해달라 자만말라 쓴소리도" ',
#  ' 위안부 피해자 그림을 그리신 선생님의 이야기를 들어봅시다.',
#  ' 물가 초미세먼지 세계 최고 관측소 걸림돌',
#  ' "내년 코스피 전망치, 그래픽으로 한눈에 확인하세요"',
#  ' 황 연휴 기간, 박용권 드려',
#  ' 엔터테인먼트 업계, 올 분기 영업익 8억 7,000만원 증가',
#  ' "선 인 능 분 천 원 투 종합" - "선 인 능 분 천 원 투 종합"은 전통적인 한국 음식점에서 제공되는 인기 메뉴입니다. 가격은 10,000원부터 30,',
#  ' 최지만 시즌 첫 홈런, 종아리 통증으로 교체',
#  ' 대통령 호 거소 방문 호 주석 본 으 부패 없는 것',
#  ' 춘천 나이야가라 한국방송대상 작품상 수상',
#  ' "콘테 첼시 감독, 캉테 로마전 출전 여부 결정" ',
#  ' 부산국제코미디페스티벌에 참여한 한국코미디언들',
#  ' 연천 영하 20도 북쪽 오후부 강 위 풀려',
#  ' 드랙퀸 연극 조지 맥브라이드의 전설 내달 초연 예정',
#  ' 이스라엘 역사: 희비극의 말 한 마리',
#  ' "기소식 부 내일 도 화재 대제"',
#  ' 게시판 제 회 한국출판학회상에 천재교육 등 선정',
#  ' 이인제, 충청을 젊은 희망의 땅으로 만들겠다 - 충남지사 출마 선언',
#  ' 말 여행 제주 취향 나자 대야 날릴 색 계곡 다 축제',
#  ' 징코데 컴바이닝 스닥 총 종합',
#  ' 네이버뮤직 바이브로 통합 기존 서비스 내년 12월 종료',
#  ' 문 대통령, 안타까움 금할 수 없어 사망자 최소화 위해 만전을 기하라',
#  ' 스페인이 4회 연속 월드컵 본선 진출, 이탈리아가 3위로 종합 순위표를 마감했다.',
#  ' 유럽 최악 한파에 난민들 피해 속출, 폐렴과 저체온증 확산',
#  ' 송 섭 회의 전국구 원만',
#  ' 동당대회, 시민사회 만나는 만약의 상황 대비',
#  ' 리 에겐 인격적 소 력 중요 과만중 독불 군형은',
#  ' "사우디 왕 살만과 유시 조 지속 합의 종합" ',
#  ' 김정은 북한 국무위원장 추정, 열차 단둥 통과 여시간 여정 개시',
#  ' 아시안게임 응원석엔 하나된 함성 벤치엔 우정의 미소',
#  ' 문 대통령, 미중러 협력 아세안 동행 통해 비핵화 동력 보장했다',
#  ' 아랍권 반 란 정상회의, 이란의 맹종에 춤을 춘다',
#  ' 평양정상회담, 남북 정상 오찬장도 함께 참석',
#  ' 답 한 빛 하 경기 초미세 먼지 주의보 대책 발표',
#  ' 연말연시 맞아 네트워크 특별대책 마련',
#  ' 광복절 북구 축제',
#  ' 네이버, 전문자료 검색 내년 안에 구글 따라잡기 위해 힘쓴다',
#  ' "민주 광역단체장 후보 면접, 지방선거 당내 경쟁 개막" ',
#  ' 텔레콤 충청 지역 폭우피해 통신망 복구 작업 시작',
#  ' 경제부 윤종원 수석, 일자리 창출을 위한 민생고용 드라이브 종합 보도',
#  ' 대통령 한불 비즈니스포럼 콘서트 참석 파리서 경제 문화외교 강화',
#  ' "공사 기간 비용 큰 사업주에 큰 부담"',
#  ' 외국인에게 말만 하세요! 한컴 이어폰형 통역기, 첫선을 보입니다.',
#  ' 이라크 프랑스인 조직원, 가차 없이 사형선고 받음',
#  ' 아힘 프라이어가 소개하는 반지 부작용',
#  ' 탈북민 도움에 한국계 영 왕, 국가공훈장 받았다.',
#  ' 프로농구 인삼공사 컬페퍼 햄스트링 부상 교체 예정',
#  ' 김현미 전월세상한제 신규 계약 적용 고려할 점 많아 신중론',
#  ' 등단 10년 차 작가 나나 지가 나갔다죠',
#  ' 추미애, 긴급회동 제안에 정해진 바 없다',
#  ' 필리핀 국방장관, 군부대에 몰래 통신 시설 설치 허용 재검토',
#  ' 청년 김어준의 뉴스공장 청취는 짧다',
#  ' "프랑스 구 해체 위 위 승 로"',
#  ' 그 픽  택 가 현실화율 세  산 식',
#  ' "지구 임계온도를 도달하지 않도록 목표를 촉구하는 인류 시위"',
#  ' 일 연 의원들과는 연',
#  ' 버려진 튜브로 만든 독특한 설치미술 작품',
#  ' 김정 평양 제3과학자거리 개발 지시',
#  ' "갤럭시S21: 삼성전자, 단독 출시"',
#  ' "일제가 쓰고 버린 태평양 섬들의 근대화는 달랐다"',
#  ' 충북과학고 최경준, 손승연 학생이 대통령상 수상한 과학전람회',
#  ' 무선 장비로 침입자 막는다, 텔레캅의 새로운 보안 서비스',
#  ' 중소기업 경기 악화, 인건비 상승으로 최대 애로 사항',
#  ' "전광 인 우승 한 풀 승하러 왔죠"',
#  ' 닷새째 경찰에 포위된 홍콩 이공대 학생들',
#  ' 대구 경북 공천면접심사 현역 진박 후보자들 격돌',
#  ' 강원 사옥, 선교센터 건물 일 착공, 월 완공 예정',
#  ' 용량 낮은 소상공인에 연간 대출 터 다',
#  ' 미스터리한 먼지 이터 물의 비밀',
#  ' 융커 장, 국 질서 탈 우 낙관 지지하지 않습니다. ',
#  ' 모범장서가에 만 천 권 소장한 이종근씨 등',
#  ' 현대차그룹 정의선 회장, 세 경영 본격화 종합',
#  ' 우리금융, 대중부유층 명중 명 노후준비 부족하다고 생각',
#  ' 광공사 페루 여 자 무장 도  의해 사망',
#  ' 긴급재난지원금 중 기부금은 5천 억원 지급액',
#  ' "디 차 전 발발 당일 유대인에 평 원 손편지" ',
#  ' 카 배당금 문재인 대통령이 다시 라 테 포 발표',
#  ' 주터키한국문화원 개원 10주년 행사 개최',
#  ' 휴턴 턴어웃 레이오, 진출 승 다',
#  ' 신당호 친노 지역구에 특별천 전면전 선포',
#  ' 프로농구 선수 두경민, 많은 것을 배운 시즌',
#  ' 베스트셀러 가벼운 에세이류가 계속 강세를 유지하고 있습니다.',
#  ' "올해 움권 면적이 1,500만㎡ 이상 확장되었습니다"',
#  ' 이달의 편집상에 매일신문 공부까지 거리두면 등 편',
#  ' 조코위 대통령과 김정은 북한 지도자가 6차 정상회담을 갖기로 결정했습니다. ',
#  ' 주말 여행객들, 강원권 남한강축제에서 무더위를 날리며 속초에서 피서철 이벤트 즐기자!',
#  ' "랜섬웨어 공격이 증가하면 대응책이 필요하다" ',
#  ' 홍영표 홍문종 염동열 체포동의안 부결에 사과 책임통감',
#  ' 폭증한 신용대출도 가상화폐 시장으로 흘러갔나?',
#  ' 삼성전자 주총, 퍼스트무버로 거듭나겠다 - 종합',
#  ' 프로야구 롯데 상무 독, 사직구장에서 열림',
#  ' 온도에 따라 변화하는 스마트 입자 개발',
#  ' 시 게 김범호, 상대 기 탄 바 인',
#  ' 남북 선수단, 지각 입장에 대한 사연은 무엇인가요?',
#  ' 스마트폰에 신용카드 대면 삑, 새로운 본인 인증 기술이 나온다',
#  ' "사람 닮아가는 의 손이 나무의 조공"',
#  ' 삼성전자, 하반기 분기별 순항 예상',
#  ' 엔터 이코 가입, 제휴 및 할인 혜택 제공',
#  ' 한 주택브랜드 공작소 론칭, 2023년 2월 발표',
#  " 고척스카이돔 체육신인 '펄츠' 복귀, 필라델피아에서 첫 경기를 치른다.",
#  ' 영상 최강 한파 패딩 목도리 중무장 전국 강추위에 꽁꽁 얼음장으로 변해버렸습니다.',
#  ' 개 언어 인도 힌디어 국어 지정에 찬반 논란',
#  ' 터키군, 시리아 진격을 위한 에르도안 평화의 샘 작전 개시 선언',
#  ' 충북 한여름 무더위 날씨는 맑음, 최고 기온 33도',
#  ' "서구팀, 재팬 핀 상금 1억 원 획득" - 최초의 한국 상업용 로봇 경주 팀이 일본을 상대로 승리',
#  ' 부산 엑스포서에서 해양안전 통신기술 시연',
#  ' 중   국회, 핵 규탄 공동 성명을 채택',
#  ' 이 서 국 강조 민 캐 다서 정 의혹 비판',
#  ' 러시아, 시리아에서 미사일 발사했나? 러시아 국방부는 부인',
#  ' 어 결정하든 해서 정사안은 수용',
#  ' 대통령 국회연설 북한 회 핵 회 대화는 제로종합',
#  ' 석촌동 고분군 발굴 조사 설명회 개최',
#  ' 2021년만의 당대회 맞아 김정은 우상화 주민불만 커져종합',
#  ' 내년 서울에서 개최되는 기 강습회',
#  ' 거 소 엔지 어링 부 중 기업부 경',
#  ' 코리아둘레길 남해안길 남파랑길로 불려주세요',
#  ' 인삼공사 이적생 트리오 알토란 활약, 성공 신화 예고',
#  ' 법정 라이프 목선 현상 해 선주 큰손실 가',
#  ' 홍콩 갑부 리카싱 올해 세계 경제 복잡할 것 모두 조심해야',
#  ' 통신망 장애시 양자암호키 회전 기 개발',
#  ' 조 사 없는 에어 트리아 시',
#  ' 핵 재처리 소듐고속 구 지속여 정종 문제 해결',
#  ' 쿠르 군 시리아에서 순찰',
#  ' 철도역 매표 상담 역무 담당 코레일네트웍스 노조 파업, 전국 7개 노선에 영향을 미침',
#  ' 작년 우리나라 낙뢰  월에만  만번 벼락 맞을 확률은',
#  ' 중동의 중재자 오만 외무 이란 방문 이란 성토종합',
#  ' 영문운전증 발급 변경 조치',
#  ' 해운업 카드 크레인 고용 증가',
#  ' 신간 마르크 의와 한국의 인문학: 새로운 인문학의 대두',
#  ' 손흥민, 북한 화제 자 잡 종합',
#  ' 수자원 국토정보공사, 데이터 중심 스마트시티 협력 강화',
#  ' 이스라엘과 팔레스타인, 가자지구 무력 충돌 중지 합의',
#  ' 이란, 신형 원심분리기 설치를 위한 핵합의 범위 내에',
#  ' 현업 노련한 방구기 견적',
#  ' 슬로바키아 언론인 피살 후폭풍 판사도 사임',
#  ' 상장 신작 대박 겹경사에 넷마블 첫 깜짝 보너스 발표',
#  ' 광주교육청, 지방공무원  명 공개 채용 공고',
#  ' 완벽한 수비로 두산을 롯데가 완파하고 승리, 고지는 선착하다',
#  ' 직장인 금융자문 받으세요 - 금감원 머니콘서트 개최',
#  ' 이도 건설 감독 황연, 활용 가치 고민',
#  ' 바이오 분야 원천기술 개발에 올해 1천억원 투자',
#  ' 새누리당 당직자들, 대선 후보들의 큰절에 응답합니다',
#  ' 이해찬 대표 취임 축하 행사 앞에 놓고 인사말',
#  ' 국토부 차관, 지방 미분양이 문제 매수자 입장에선 좋을 수도',
#  ' 문승, 산 중심타선 못넘고 이닝 4실점',
#  ' 그래픽 자영업부채 1조 돌파, 자영업대출 규모 급증',
#  ' 신종 코로나바이러스 감염증 2차 대유행 속에 촛불의 눈으로 동네를 밝히는 사람들',
#  ' 유엔총장 시리아 휴전 환영 유효한 해법은 긴 여정',
#  ' 이해찬, 철도 공동조사 내주 시작...남북관계 큰 변화',
#  ' 문 대통령, 독립운동 역사 공유하면 북의 마도 가까워진다',
#  ' 코아로직 수원지법에 회생절차 종결 신청서 제출',
#  ' 안경사는 보행기 안되고 경찰관 공채 신체 기준 논란',
#  ' 경제자유구역 지지부진, 개발 지연, 국내기업 역차별 탓',
#  ' 극장에서 개최되는 대통합 축제',
#  ' 전북 주요 대학들 등록금 동결 학부모 부담 덜겠다',
#  ' 금융시장 충격 일단 소강국면, 주가 낙폭 줄고 환율도 하락',
#  ' 신간 미래를 어떻게 결정할 것인가? 매일의 빵을 어떻게 준비할 것인가?',
#  ' 최소 8도 오른 따뜻한 날씨, 중부 지역 밤늦게 약간',
#  ' 총선  개월 앞인데 선 구  정 안갯 정 인 발 동',
#  ' 프로야구 앱 출시 사흘 만에 100만 다운로드 기록 ',
#  ' "사진 전, 노우노 이와이 도시 별"',
#  ' 재즈 디지털아트 설치미술과 만난 무용 더 탑핑',
#  ' 에버튼 득점왕 순위 루카쿠 몸 로  억원 기록',
#  ' 이란 원자력청장 포르도서 우라늄 농축 농도 20%까지 올릴 것',
#  ' 김은절, 로드먼 교수와 함께 가포에 대한 논의',
#  ' 이집트에서 성폭행하려 한 남성을 살해한 세 소녀, 처벌 논란',
#  ' 톈안먼 진압 당시 장교 공개 참회, 기억해야',
#  ' 경기도 첫 번째 하치코 운행업체 설립',
#  ' "수퍼 타타 점프 사스, 연속 승리!"',
#  ' "자랑스러운 양언론인상 수여식"',
#  ' 그래픽 한국은행, 지난해 순이익 3년 만에 최대 기록',
#  ' "랜 정시 배후력 대규모 작전 안정회" ',
#  ' 프로배구 최하위 한국전력 우리카드에 고춧가루 역전승',
#  ' [여기에 복구된 헤드라인을 작성하세요]',
#  ' "바 개인투자 지 대소액투자자" ',
#  ' 세종시, 력력 있는 여성 재업용 유 등지 화',
#  ' 출근길 기상 악화로 인한 교통 정체 전망',
#  ' 증시신 주가 급등, 뉴욕 증시 상승세로 외국인 투자자들이 동남아시아 펀드에 몰릴 것',
#  ' 한-뉴-신 도중 꼴',
#  ' 호 올스 전 홈 스 결  진출: 축구팀 호 올스 홈 스 결의 결승 진출',
#  ' 돌아온 추위 전북 최저',
#  ' 영국 장관, 브렉시트 공식 발표일 미정으로 연기 지지',
#  ' "자동차가 도로에 들이받아 인명 피해 발생" ',
#  ' 박근혜 정부 전환위해 내각 개혁 어렵다',
#  ' 팅 씨, 인  팅틴 백 구조에 참여했다',
#  ' 인천 공립유치원 교사 근무 중 코로나19 확진',
#  ' 레카 전맑가씨 해 은 내 까 고 비',
#  ' 트레이드 베이스로 무기 무역적자 불 종',
#  ' 철원이 되는 산불, 주말에 발생한 피해 규모',
#  ' 경북 안동에 대규모 정비 도 추진',
#  ' "반 성인식',
#  ' 기가지니 내일부터 금융서비스도 척척종합화면 제공',
#  ' 지주회사 해외사례 연구 공정위 진행',
#  ' 경찰 소재 영화 방송인 맞는 민갑룡 경찰청장',
#  ' 감사원 수 과학 구소 연구보다 워크 강연',
#  ' 유콘시스템, 드론용 솔루션 개발을 위한 협력 파트너십 체결',
#  ' 한중일 정상 특별성명 채택 비핵화 목표 환영, 국 공동노력 강화',
#  ' 튀니지에서 아랍연맹 정상회의, 트럼프 대통령의 골란고원 선언 비판',
#  ' 애플 올해 출시 예정인 신형 제품',
#  ' 중소기업에 대한 연간 폼 공개',
#  ' 사무국의 노력으로 미국에서 야구를 하는 아이들이 다시 늘었다. ',
#  ' 네이버 검색 광고, 전체 광고 매출의 60% 차지',
#  ' 양 완 조기종료 가능성, 원달 환율 하락 영향',
#  ' "페이스북은 왜 콘텐츠를 삭제하지 않나요? 누가 이를 알렸나요?"',
#  ' 또아 예비 자 서 분양 종료, 5,000세대 남아',
#  ' 당정 지침에 따른 코로나19 예방 방역 규정 연말까지 지속',
#  ' 하루평균 수출 감소폭 전월보다 줄어, 향후 예단 쉽',
#  ' 골 스테이트 클럽과 블랙 프렌즈가 만날까',
#  ' 국회의원 당선 성분 분배 선지확대로 경쟁 다',
#  ' 알뜰폰 헬로모바일, 청소년 요금 반값 할인 시작',
#  ' 노벨상 수상을 노리며 화합의 회의 개막',
#  ' 정상회의에서 균 심각한 목소리로 인한 영향에 대한 논의가 진행된다.',
#  ' 러시아 역 폴록 점',
#  ' "아시아 여자축구 국가대표팀, 신진 선수 발굴을 위한 캠프 개최" ',
#  ' 게시 예산 독거노인 고치기 봉사활동',
#  ' 홍콩 시위에 원격조종 사제폭탄 등장 경찰, 테러리스트와 비슷',
#  ' 페이스북, 개인정보 보호법 위반에 따른 1억 5,000만 원 과징금 부과',
#  ' 시판 주금공 한국의 주 융 100억원 확보',
#  ' 뉴 랜드 대학 시위 지속: 학과 본토 학',
#  ' 월 주식 발행액 전월비  증가 유상증자 1,200억 원',
#  ' 월미도 새 모노레일 내년 추석에 달릴 수 있을까?',
#  ' 민황 두 투이 치, 데뷔 성공적',
#  ' 대형 서점에서 찾을 수 없는 네 가지 독서 방법: 판사들의 추천',
#  ' 시티 리버가 아스널을 상대로 5년만에 프리미어리그 우승 좌절',
#  " 조소앙이 쓴 독립운동 평전 '유방' 역",
#  ' 애플, 이폰 초청 행사 취소... 김영란법 때문에 문제 발생',
#  ' 베트남 기업가들은 삶의 무게를 어떻게 견디나요?',
#  ' 신용카드 사기 방지를 위한 새로운 시스템 도입',
#  ' 든미령계곡 어린이 방역 강화',
#  ' 코로나19 신규 확진',
#  ' 일요일부터 청년회 전쟁 여소 국, 패',
#  ' 실군 섬진강댐 방문한 김 조 부 장관',
#  ' 단교  개월만에 카타르 왕래 화물선 허용',
#  ' "바셀린을 뿌리는 갤럭시 5 행사, 준비는 한창! 천여명 몰릴"',
#  " 북한-중국 합작영화 '평양에서의 약속' 방영",
#  ' 대통령 에어포스원 탑승한 오바마, 분간 북핵 대응 긴급 통화',
#  ' 이적설에 휘말렸던 이근호 울산이라 마음 갔던 것이 사실임',
#  ' 박지호, 에이스로서의 바탕',
#  ' 못판다 난 조 천 치 매각종',
#  ' 미 에셋대우 신한  실적 배당 목표',
#  ' 국회사무처, 추첨으로 의료대학 입시일 확정',
#  ' 사이버도박 증가 추세 올해만  건 적발',
#  " 인천서 '라벤더' 행사 성공",
#  ' 초대북사파 발표 서훈, 정유력 종합',
#  ' "2023학년도 대학교 입학 편입생 모집 카톡 진행"',
#  ' 이통시장 태풍의 눈 단말 자급제 수면 위로 업계 예의주시',
#  ' "퍼스 실점 0, 닝보 무실" ',
#  ' 서울 초등학생 새학기부터 구강검진 결과 스마트폰으로 확인 가능',
#  ' "통신업 종사자, 코로나19에 따른 경제 위기 극복을 위한 정부 지원금 수령" ',
#  ' "리히는 1월부터 이서 고위 경제 화"',
#  ' 올림픽의 답변으로 신소정 등장',
#  ' 성 갤, 제치고 영상 위종합에서 우승',
#  ' 유럽 리그 아 라운드 패 수모 별 리그 탈락',
#  ' 대박 오일길, 제 경고 압박종합',
#  ' 오마이사드는 수익 방안 제시 위협에 대응',
#  ' 롯데건재, 폐수 슬러지 건조기술 환경 인증서 획득',
#  ' 대북 북핵은 턱밑 비 해결 없으면 한미에 큰 피',
#  ' 프리미엄 임대폰 제공 일 이하도 하루 단위 과금',
#  ' 아시안게임 여자축구 인도네시아 상대로 손화연 이현영 4-2 승리',
#  ' 부교육청, 식종자 등 개육공무직 발령',
#  ' 아베 총리가 만난 국회의원들이 칙령 위협 주장 합의',
#  ' 민간강 검진 결과 받았다고 합니다.',
#  ' 국토교통부, 공동주택 관리 우수 지에 서울 텐 힐 단지 선정',
#  ' "다가 아마존, 짝 명 천 망신"',
#  ' 제2차 세계대전 종전은 새로운 폭력의 시작이었다',
#  ' 유엔 아 공습으로 일간 민간인 100명 이상 사망',
#  ' 이란 보수 싱 탱크, 제재 대상에 올',
#  ' 대중교통 정체로 인한 혼란',
#  ' 예약판매 시작, 액정 무상 수리 등 1만원 할인 혜택',
#  ' 국문협 상에 임 훈 안 순 육 박예 수상',
#  ' "밀린 통신비 신용등급 반영한 즉시 중단 종합 보험"',
#  ' 구산 사이로 또 한 해가 지나 충남 해넘 명소 북',
#  ' 금융사 가상화폐 경계령 비자 거래처리 안할 것',
#  ' 대관령 영하 4도 나흘째 맹추위 동해안 건조특보',
#  ' 사상 최대 석유 가치, 달러가 폭락한다',
#  ' 폭우로 산마을이 큰 피해를 입었다',
#  ' 국방부, 사드 배치에 대한 언급 없이 역량 강화 심의 진행',
#  ' 공안 장쑤 화학공단 폭발 참사 책임자들 구금',
#  ' "조선 피격 드론 추 추락, 호위무장함 협력으로 격추" ',
#  ' 한미훈련 협의, 국방성 종합계획 발표 예정',
#  ' 회계사 반: 경기 상반기 성적이 상향 조정됩니다. ',
#  ' 홍준표 지사가 회견장에서 기자회견을 진행합니다.',
#  ' 홍남 차관, 나 술 안 관리 검사',
#  ' 서울시 공무원이 주점서 성희롱하고 난동부린 대취객 잡혀',
#  ' 아프리카 시장 공략, 엔터테인먼트 산업의 새로운 도전',
#  ' 호 진시 발사, 천 안까지 한 큰 도약',
#  ' 제 기 여론집중도조사위원회 출범, 위원장에 김영욱 교수 선임',
#  ' 양정상회담 문 대통령과 문 대통령이 모임에서 무말을 놓쳤다',
#  ' 신서 위반 직자 증가 교황청 리지침 존재한다고 발표',
#  " 물로 덮인 '터월드' 행성에도 체 존 능",
#  ' 위클리 스 트 어린이날 국 과학관 행 다채로운 이벤트로 즐거움을 선사합니다.',
#  ' 르담 붕괴 위기 대응 전 당국, 긴급 보강 작업 착수',
#  ' "폭행 혐의로 던 우 아스가 1만 5천만 원을 결제하다"',
#  ' 암과 질병의 개발: 이질 쏘쥐의 실체를 밝혀내다',
#  ' 간호사 기와 외 음 타: 간호사의 기와 외 음 타는 어떤가요?',
#  ' 코로나19 팬데믹 이후 산속의 달러 강 달 선물 거래 익률이 급격히 증가했습니다. ',
#  ' 학자들이 술과 담배의 위험성에 대해 논의합니다. ',
#  ' 국회 외통위, 한미 방위비분담금 협정 비준동의안 처리',
#  " 신간 '자바 데리'를 읽는 간포퓰즘 주의자들",
#  ' 특검 이화대 및 관계자 사무실 택사 부색 보',
#  " 전자, 실속형 스마트폰 '2022년형' 'Z 시리즈' 공개",
#  ' 참석자와 인사말을 전하는 안희정 대표',
#  ' "책임총리 내각의 단계적 교체론도 대두" ',
#  ' 바흐의 모테트 전곡 연주, 박유신 김현정 듀오 공연',
#  ' 그래픽 작년 주식 평균 인당 보유 종목 수 25개',
#  ' 국민당 당내 성추문, 출당 요구 가속화',
#  ' 의료 레크리에이션 전문가, 한 입장에서 제시합',
#  ' 푸틴, 시민들의 안전을 위한 테러 법에 서명',
#  ' 서북부 지역, 낮부 평년 기온 상승',
#  ' 파리 생제르맹 위반 여부 조사 착수',
#  ' 엔진 부품 판매 재 공급 시장 출범',
#  ' 대선 출마 앞둔 바이든의 나쁜손 또 폭로, 코 비비려고 했다',
#  ' 구글의 진화: 지금까지의 변화와 미래의 얼굴을 알아보세요.',
#  ' 오세훈 시장, 코로나19 대응에 권역별 리소스 배분 전환',
#  ' 올림픽 한반도기 흔드는 북한 응원단의 열띤 응원',
#  ' "쌍둥이 호주, 동시에 딜을 하려 합니다"',
#  ' 오늘 전대투표 막 올라, 파전 승자 판가름',
#  ' 무환율에서 보까미 쟁투쟁 방위로 전선 확대 종합 보',
#  ' 시진핑, 낙서 민생행보까지 만 1억 5천만 명 해소',
#  ' 에 업 력 이지로 바  연결',
#  ' 김부권 전 여사, 이달 안에 결정 단 앞에 얘기합니다.',
#  ' 중국인 래퍼 인터넷 생방송 중 손가락 자해 행동 논란',
#  ' 아프리카 남수단 서부 지역 폭력 사태로  명 사망',
#  ' "세계 집값, 올해말까지 20% 폭등예상"',
#  ' 이란 핵합의 명운 건 막판, 꽃피우는 촉망되는 합의',
#  ' 가상화폐 업자들 전기 싼 이란에 원정채굴 요청',
#  ' 스웨덴 여자축구대표팀 유니폼에 여성인권 캠페인 문구 추가',
#  ' 한 날 느낌있는 글쓰기의 세 가지 요소',
#  ' 매드 타운즈버그 강정호와의 특별한 만남',
#  ' "총영사관, 한인학생회와 취업정보 공유"',
#  ' 주춤한 동장군 다시 찾아와 강원 일부 지역 한파주의보 발령',
#  ' 한국 여자축구 아시안컵 한일전 무승부, 첫 승 무산',
#  ' 특징주 수산아이앤티 코스닥 상장 첫날 상한가 종합',
#  ' 김기식 논 정면돌파 태세, 선관위 권해석 결과가 수록',
#  ' 태국에서 텔레콤 트리페이 서비스 시작',
#  ' 에스 유  억  스플  이 제조업체와  급계약',
#  ' 시판 제조업체 청년 래대학생 기자단 집',
#  ' 아프거나 월급 못 받으면 축은행 상 예',
#  ' 강원 전교조 등원 인  개 초래',
#  ' 삼성전자, 트래블 플랫폼 긍정적 평점 수시사',
#  ' 전자제품 미국서 사면 구글 홈 기프트',
#  ' 프로농구 샐 리캡에서 80억 원의 금액을 올랐다.  (원본의 길이와 구조를 최대한 유지하면서 의미를 유지하고, 누락된 숫자를 추론하여 채워',
#  ' 티맥스, 인공지능으로 삶의 질을 혁신적으로 변화시킵니다.',
#  ' 도쿄 올림픽 개막식에 사사키조지마 배터리 시구',
#  ' 북한은 설에 3일 연휴로 지정',
#  ' 기자, 해병대 목사 이란 수만 명에 자원 미국인들',
#  ' 이라크 군경, 반정부 시위대에 또 발포',
#  ' 북부시군 존주의보 시간 해 종합',
#  ' 프란치스코 교황, 오는 11월 난민 난민 조력자들을 위한 미사 참석 예정',
#  ' 2022 시안게임 체육 코리아 우승, 여자 농구팀',
#  ' 서울시립미술관서 추상화가 한묵 첫 유고전 개막',
#  ' 사건 실격, 라 극 체 월',
#  ' 손 민의 토트넘 챔피언스리그 레알 마드리드와의 대결',
#  ' 이란 반정 위서, 행 관 서 주모자 구속',
#  ' 그래픽 줄기세포 이식 파킨슨병에 효과, 연구 모식도 공개',
#  ' 메르세데스-벤츠 바르셀로나 빌바오 두 팀',
#  ' "잭슨, 역대 최다 기록을 눈앞에 두고 10번째 유니폼을 입었다."',
#  ' 베스트셀러 언어의 온도 출간  개월 만에  위 올라',
#  ' 원 책회의 발은 홍영표, 서울시장 후보 경선에 나선다',
#  ' 마라톤 선수단 올림픽 참가 자격 위기',
#  ' "출근 한 출판 경마 클래스" ',
#  ' 근로자 휴가 지원 사업 참여  명 강릉 컬링 센터 바다 부채 길 관광',
#  ' 조성호 제안, 이한샘 상으로 소년 전 금 기부',
#  ' "기자 경례하, 이홍영 작가" ',
#  ' 무수단 미사일 발사 준비 도발 대비 감시 강화 종합',
#  ' 로 쓰레기통 관리해요',
#  ' "선제적 입막음, 사이 안 논의에 끌어들여" ',
#  ' 방송작가 집필 표준계약서 도입 시행',
#  ' 김정은, 평양에서 하노이까지 기차로 갈 용기 대분분',
#  ' "만 신간 \'한강\' 리, 리뷰 올"',
#  ' "림픽 컬링 예선전에서 낙연 총리가 하향 조정" ',
#  ' 특징주 바이오랜드 줄기세포 아토피 치료제 사업 진출에 강세',
#  ' 이스라엘 이미 숨진 팔레스타인인 총격 용의',
#  ' 스템반도체 설전 과 범: 정부 지원 확대 추진',
#  ' 무급 휴직 3일 이상만 해도 고 유지 지원 준다',
#  ' 거래가 활발한 역세권, 신반포역 거래가 500억 육박',
#  ' 스키점프 세계선수권 한글라데가 나온다',
#  ' 플 스 소상공인 위한 장기 저금액 장기키지 출시',
#  ' 고려대 동아리활동서 확진자  명 발생 방역조치 중',
#  ' 파주에너지서비스 지분 매각 절차 진행',
#  ' 다시 라이트로 김희진, 올림픽 본선 진출과 메달만 보고',
#  ' 렘린궁 김정은, 하반기 러시아 방문 합의',
#  ' 백 월 체  집회 폭 사  흉 무기 발견',
#  " 과학 소설 작가 아지 스가 쓴 '계산기 개론서' ",
#  ' 팀 쿡, 애플 배포를 통해 증강현실 기술 본격화',
#  ' 사회정의를 분배 문제에 가두지 말라 지배와 억압 제거해야',
#  ' 또 불법 갤럭시 매장서 1만 원 징수',
#  ' 아스널, 스토크시티에 대승... 리버풀에 승점',
#  ' 김영란법 합헌, 더민주 다행스러운 일 투명사회 노력 계속',
#  ' 프로축구 한가위에도 격한 순위싸움 하위스플릿 탈출',
#  ' 조사거부 개별 안건으로 방통위 첫 단독 처리종합',
#  ' 현대모비스, 주식 가격 상승에 따른 경영 강화책 발표',
#  ' 교통정리 클린 목리크 행동은 안',
#  ' 증시신상품 한투증권, 대출채권 투자 부동산펀드 판매',
#  ' 보수논객 변희재, 속심사 블릿조 포에 정직한 혐의에 대한 변론',
#  ' 민주당, 한국당 압박 지속 헌정질서 파괴 옹호',
#  ' 예스24, 우리가 사랑한 인의 작가들, 부산서 전시',
#  ' 반 사우  공격  사 디  응 다려 제안종합',
#  ' 오늘은 개교 등교식을 송년회에서 개최합니다. ',
#  ' 사고 눈치 스피싱범 검찰에 기소',
#  ' 대통령, 목표 선 경계 못하고 국민께 제대로 못알려 철저 점검 종합',
#  ' 네이버, 유니콘 기업 인정받아 호평 받았다.',
#  ' 반전을 위한 삼국 시대의 휴전을 발판으로',
#  ' 코모서에서 정정불안으로 인한 총격 사상자 발생, 정부 요원 철수 명령',
#  ' 여자농구 신한은행 팀 최소 득점 기록 2 점 불명예',
#  ' 그라 리 디지털 콘텐츠를 상품으로 만드세요',
#  ' 안 득점 대 발 후 해 승리',
#  ' 페이스북, 읽는 시간 뉴스피드 랭킹에 반영, 낚시 기사에 불이익',
#  ' 세기의 대국 알파고 아버지 허사비스, 바둑에 매료된 이유는 무엇인가? ',
#  ' 란 최고지 자 예멘 군 지지 표 사우디는 범죄자',
#  ' 정 가장 먼저 홈런을 친 선수는 누구인가?',
#  ' 게시판 자랑스러운 한양언론인상에 임철순 이숙영 수상자 발표',
#  ' 남성 4명, 관광객 1명, 버스와 충돌해 2명 사망',
#  ' 넥슨 게 버 진 개발사 아이펀팩 리에 전 적 투자',
#  ' 윤종규 금융 회장, 개월 만에 자사주 천주 매입',
#  ' 한국보스니아 축구 평가전 시청률 5.8% 급증',
#  ' 카카오톡 방 검색 노출 개인정보법 위반 소지 약화',
#  ' 대신 데 케미칼 자사주 소각 긍정적 효과',
#  ' 크리스티아누 호날두, 올해의 팀에 선정... 선수 0명',
#  ' 법무장관, 페이스북에 메시지 서비스 암호화 중단 요청',
#  ' 2021년 11월 19일, 다이아몬드 포유류 발견',
#  ' 첫 주말, 가을이 시작되기 전 야외로',
#  ' 개인정보 인인증서 유출 사건이 급격히 감소하는 추세입니다.',
#  ' 처음 터널 나누어 택시 대여료 내 부담',
#  ' 프로농구 삼성 꺾고 하루 만에 공동 1위',
#  ' [복구된 헤드라인을 여기에 작성하세요]',
#  ' 러시아, 우주 공간에 요격미사일 시스템 배치 말라 - 국제사회 경고',
#  ' 월 세계에서 가장 많이 팔리는 스마트폰은 삼성폰',
#  ' 고교 시설의 위수여식',
#  ' 비자나무는 모기퇴치제 옛 문헌 속 생물활용서 발간',
#  ' 세 의 대국 구글 수뇌부 서 집결 알파 자',
#  ' 온 형님들, 염기훈의 부상 날린 멀티골 활약',
#  ' 민주당, 최저임금 후속책 마련 한국 대통령, 공약 폐기하라 종합',
#  ' 전몰자 추모, 귀비꽃 양 제 화를 위한 특별한 의미',
#  ' 제주도 경찰의 주년 경찰의 날 축제 성료',
#  ' 필리핀 토지은행, 리잘상업은행, 한진중공업 주식 취득',
#  ' 위클리 스마트 이산화탄소로 화학원료를 잎의 선물 인공광합성',
#  ' 문 통 빠진 전선, 바람직하다고 대로 공감대 형성',
#  ' 심청이 장문의 본 에 닿고 습니',
#  ' 초신성 폭발 관측 최단 기록 시간 기록',
#  ' 한투 정부 정책방향 소폭 전환 경기하강 방어에 긍정적 효과를 가져옵니다.                ',
#  ' 증권 시장 개업종 최악의 상황',
#  ' 사천 원자력 발전소, 명실상부한 에너지 중심지로 부상',
#  ' 이라크 반정부 시위 사망자 수가 여명으로 늘어났다',
#  ' "세계 최대 크기의 굴착기와 크레인, 한국에서 최초로 등장"',
#  ' 네이버, 자율주행차 핵심센서 개발 이스라엘 기업에 투자',
#  ' 프로농구 선수 윤호영, 수술비 원 지원',
#  ' 김관 연동형 거주권 바꿔 통일해야 합니다',
#  ' 대통령 원연이 입장할 때 기차가 정차합니다',
#  ' 홍콩 과격시 제보, 고액 억천만 현금 거래',
#  ' 축구 경기 표 출 수 학영 승부 작 혐의 속',
#  ' 금융 산업의 차기 장 최종 보고서 발표 성공 합',
#  ' 대북특사단 오전 9시 평양 안착 시부터 회담 중 보',
#  ' 용 중인 노트 이미 팔린 만대, 어떡하나?',
#  ' 벚꽃 축제 와인 마시며 봄을 즐기세요',
#  ' 텔레콤, 인텔과 협력해 기반 자율주행차 개발에 나선다',
#  ' 중국인의 인건비 급상승 영향',
#  ' 서자치구, 곳곳에서 형아들이 트랙을 당겨 형을 추월한다',
#  ' 재벌닷컴 재벌 총수의 자택 공시가격 상승',
#  ' 김욱, 전 경남에 첫 안기며 도약',
#  ' 만 기 연속 탬이 연',
#  ' 장미의 이름 새 옷 입히니 젊은 독자들 호응',
#  ' 투 디 데이 투 디 데이: 한국의 역사, 문화, 여행을 둘러싸고 있는 이야기',
#  ' 문 대통령 국정지지도, 지난주보다 상승 - 갤럽 종합 조사 결과 발표',
#  ' 외화벌이 기관들 무역허가권 확보 경쟁 심화',
#  ' 문 대통령, 북미 평양 제수에 참여하며 북미 수교 확대를 위한 노력 재개',
#  ' 이 신 비스 장애로 1,000만 명의 환자가 고통받고 있다.',
#  ' "2022년 4월 11일, 짱기 리 스커 누구 기가 통한 영상 공개"',
#  ' "2022년 국제 웹 콘퍼런스 개최"',
#  ' 에스티 이  억  규모 플  제조장비 공 계',
#  ' 아나운서 성 해소 위 권고 용',
#  ' 러시아-우크라이나 전쟁, 러시아 통화 도달 상승',
#  ' 서울 표준주택 공시가  억 초과 고가주택 정밀 조준종합 보',
#  ' 연세대학교, 상용망 기반 연구 플랫폼 출범',
#  ' 국장단 대표, 평화길에 큰 발전 기여',
#  ' 대는 유튜브 세대 하루 3시간 30분 본다',
#  ' "영상: 류현진, 베이스 량 포수 마틴과 출싱은"',
#  ' 오빠 감독 문경은 이상민과 크리스마스에  점슛 대결을 벌였다.',
#  ' "탁월한 향상 배구 팀 전임 감독 선임, 하겠다"',
#  ' 세계 1위 신망 단 선수가 올림픽 눈앞에 있다',
#  ' 춘천시 환경사업소, 지역 환경 보호를 위한 신규 사업 발표 기자회견',
#  ' 미 대북정책 이란과 달랐다 전략적 인내',
#  ' 야구 경기에서 더욱 생생한 경험을 선사합니다',
#  ' 국 사개혁 명분 정권, 맛 맞는 인적이 안돼',
#  ' 디지털 티켓 박스 필수',
#  ' 특징주 두산솔루션 분할상장 나흘째 상한가 종합',
#  ' 해외령 기아나 노조 표단  기  무 한 점  농성',
#  ' 이란, 제재 면제 직전 감시 교환자 합의 보장',
#  ' 하원, 내일 트럼프 탄핵안 표결...여야 막판까지 대충돌 종합',
#  ' 헌장 서명식, 부겸 장 참석',
#  ' 내일날씨 새해 첫날 전국 가끔 구름 많음 아침 기온 영하  도',
#  ' 갤럭시 S21 5G 전패키지 나 다채로운 한정판 판매 시작',
#  ' "타 음을 위한 최고의 스마트폰: 최신 기술과 기능"',
#  ' 최대 매트 밤의 전배 경 구',
#  ' 고속도로에서 식사를 하는 운행 중 차량',
#  ' 원스토어 앱 유통 수수료 인하, 3%까지',
#  ' 위메프, 국내 최대 온라인 쇼핑몰로 성장하다',
#  ' 대규모 정상담 재난 논의 종합',
#  ' 주 사회서비스 급 사무 장 등 부 직원 100명 공모',
#  ' "트럼프 대통령이 주장하는 것처럼 불법 이민자 전원 추방시 미국 경제 축소"',
#  ' 불교계, 육식 금지 언제부터 시행될까',
#  ' 용산구 최고위원 출마 난민단체 위해',
#  ' 민주당, 평창올림픽 성공 개최 총력전 - 색깔론, 한국당 맹공',
#  ' 창녕, 도 육박 불볕더위 물놀이 여름축제로 더위 탈출 종합',
#  ' 해운 위기 용 료 인하 합병으로 해결될 것이라는데요',
#  ' 현대판 파라오, 엘시시 이집트 마지막 독립 언론도 겁박',
#  ' 이주열 한국은행 총재, 통화정책 완화정도 추가 조정 필요',
#  ' 대규모 윈도우 점 율 최초 공개',
#  ' 인민일보 중국 내정간 비열한 행위 비난',
#  ' 아 존, 전 북미 최고의 애 치열한 경쟁자',
#  ' 토요일, 애 레 듀오, 넷플릭스에서 스트리밍!',
#  ' 지난달 분양 2천 채 개월 연속  최고세일',
#  ' 변호사 라건 떠오른 대성 현대모빌리티 표팀',
#  ' 연역 터미널에 성객 공항 관광객 북',
#  ' 개막전 선발 후보 류현진, 시범경기서 마지막 점검을 통해 최종 선발될까?',
#  ' 중부지방, 일주일째 장마 끝나고 푹 찌는 날씨가 이어진다',
#  ' 극적 역전승 김종민 감독, 한 세트만 따면 반전 오리라',
#  ' 블랙 컨트리 부킹 비마 패거리 참견 라',
#  ' 대법, 영원무역 비판기사 한겨레 정정보도 손배 책임 없다',
#  ' "책 읽는 여성의 흑역사 전혜린을 위한 변명"',
#  ' 대리마전시회 출범, 리마스터링 마우스폰 출시 예정',
#  ' 내일날씨 제주도 영동 아침까지 비 동해 남해 풍랑 주의',
#  ' "리랑카 말라리아 위기, 정부가 발빠르게 대응한다"',
#  ' 선 제  스트트  정 독 타도 치  한국 - 선박 제조업체, 한국 시장 진출 계획 발표',
#  ' 삼성전자, 퀄컴과 함께 국제 표준 기반 데이터 통신 성공',
#  ' 한전 감사위원에 이성한 전경찰청장 조전혁 전의원',
#  ' 세 호 단체들 참사 보도 책임자 공개',
#  ' 특징주 메가 디 자회사 합병에 급등',
#  ' 구미공단 업체 경영계획 원달러 환율 1천 원 상승',
#  ' 김지 선수, 현대캐피탈에 깜짝 득점으로 승리',
#  ' 유엔, 북한 블랙리스트에 누가 올까… 직대사 첫 발표',
#  ' 고용안정지원금 오프라인 신청 첫날 한숨 돌리게 됐어요',
#  ' 서일째 단독 입원, 건강 악화로 병원 종합 진료 받다',
#  ' "정의장 인 카흐탄, 대통 담에 참석"',
#  ' 러시아 미사일 도입, 부품 공급 중단',
#  ' 농축 라늄 저장한 핵 발전소',
#  ' 세계문화예술교육 주간 전국 행사,  일 개막 문화예술 행사',
#  ' 금감원, 공공기관 지정 피했다...년도 상위직 50% 감축 종합 보',
#  ' 튜르키예와 러시아 간의 생상품 거래 발전 방안',
#  ' 아널드 슈워제네거, 링컨시와 전 대통령을 격파하다',
#  ' 경기, 권투 경기, 존주가 활약',
#  ' 네이버 투데이 스타트업, 배달앱류 서비스 출시 예정',
#  ' 스피드 호에서 코리아 국사자 전환',
#  ' 트럼프는 한사코 부인했지만, 멀베이니는 우크라이나에 대가성을 인정했다고 종합했다. ',
#  ' 남북 일농 경기대회 방북단 군용기로 내일 평양 방문',
#  ' "작은 귀 기울이, 권 극제"',
#  ' 전 법 폐지 청원에 연 문 대 해',
#  ' "나, 위기 속에 빠진 복지 대타협의 수령종합" ',
#  ' 모코리아, 이팔코리아 세 가지 혐의로 소송을 제기함',
#  ' 베트남 일본 기업, 해양 개발 투자 호소 마리오처럼 싸우겠다',
#  ' 화이트 그래핀, 대면적 합성 성공',
#  ' 북한 협력 기금은 올해 3억 4천만 달러로 전년보다 2억 달러 증가했습니다.',
#  ' 대선 전, 신태영 후보가 우선 순위로 선정',
#  ' 이탈리아 방문을 앞둔 시진핑, 일대일로로 양국 관계 새 시대 열어간다',
#  ' 아프리카 외무 장관, 내전 국가 화요일 방문 예정...사적 해법은 안 된다. ',
#  ' 용 간 앱, 네이버와의 협업으로 인해 드디어 출시됩니다.',
#  ' 매본의 국경 복판에 도',
#  ' 이강인, 대표팀 스코틀랜드에 패배하며 골 없이 무승부',
#  ' 최지만, 보스턴전 멀티히트와 호 솔로포로 강력한 활약',
#  ' 사사구 10개 남발한 브리검 김 성 호 비  분에',
#  ' 이탈리아, 프랑스 정상 간 난민 자동 배분 시스템 도입 합의',
#  ' "픽 유료방 점유율 상승 이후 전망 밝아" ',
#  ' 론 율주 차 등 무인 동 개발에 억 투자종',
#  ' 삼 그룹주 재용 영 CEO의 기각 판결에 동반된 대규모 집회',
#  ' 아트시스 도와 대규모 수준',
#  ' 북아프리카 스페인령 세우타 이슬람교회당에 괴한들 총격 사건 발생',
#  ' 클래식 음악의 멜로디로 물들다',
#  ' 2023년도 취재 관련 언론사 압수수색 어수선한 채널 종합',
#  ' 프랑스, 이란의 란탄 미사일 발사',
#  ' 경찰, 두산 이영하에 승부조작 제의한 브로커 수사 착수',
#  ' 서던캘리포니아 주에서 한 마리의 북극곰이 내일 영하 20도까지 온도가 떨어질 것으로 예상됩니다. ',
#  ' 간 내 몫의  랑을 탕 고 지  당신 만',
#  ' "슬픔 속에 난민 단체 배치" ',
#  ' 대령 핵 가스회 탄핵 정기 무게용',
#  ' 러시아, 프리시즌 전 건설로 석유 다량 생산을 돌입',
#  ' 북한의 현지 적비 등장',
#  ' "스크린  함  란 갤  폴드 조롱 동 상"',
#  ' 대 일 아시아 정대영 대 박은진, 2차전에서 승리!',
#  ' 이애미 리 트 서울옥 블로우아웃',
#  ' 기가지니 더욱 작아지고 간결해진 버전 출시',
#  ' 생명보험료 시도 정부, 실손보험료 인하 시도 말고 해봐요',
#  ' 오바마 행정부, 순수한 방어 체계 위협에 대응하기 위한 사드 배치 발표',
#  ' 구르반탄압 항의 키위에 나쁜 세력의 도전',
#  ' 충북교육청, 교육의 틀을 바�',
#  ' 한국에서 윈도우 에디션 출시 공략',
#  ' "롯데, 두산 선발 승에 불과했던 경기에서 승리"',
#  ' 애플, 이스루마 1000억 원 규모 투자 대박',
#  ' 특검, 뇌물죄 수사 공식화...최순실 뇌물 피의자 조사',
#  ' 인공지능 컴퓨터, 마침내 프로 바둑 기사를 이기다',
#  ' 박건우 삭발은 인제 그만 올해는 초반부터 잘할 겁니다',
#  ' 구글, 페이스북, 중국의 알리페이로 결제 기능을 추가합니다',
#  ' 북한, 이란에 전한 핵 올해 화제로 전해진다',
#  ' 야구 레크리에이션 대회 참가자들, 신나는 경기를 즐겼다',
#  ' 온대지역 의료 시스템 개선 제안',
#  ' 비가 내리면 어촌의 해수욕장에도 피서인파가 몰린다.',
#  ' 여자배구 디우프 인삼공사, 순위 끌어올리기 위해 노력한다',
#  ' 관영 매체, 시위 지지 란속 개막전 중 불발',
#  ' 대통령 의혹 사건, 은닉 정황 발견',
#  ' 중국 항공과 대한항공이 항공 운임 전쟁을 벌이고 있습니다. (완전한 제목: 중국 항공과 대한항공이 항공 운임 전쟁을 벌이고 있습니다.) ',
#  ' 한국기자협회 창립 25주년 기념행사',
#  ' 장소 고기장 비세운',
#  ' 충북 대 로 맑다가 밤부터 구름 낮 최고 기온 도',
#  ' "오부과천동안주의: 새로운 규제로 지역 경제에 미치는 영향"',
#  ' 늦어지고 있는 단풍, 오대산과 설악산은 절정에 이른다',
#  ' 세계 3대 산 모인 한국과 영국이 개최',
#  ' 홍콩 주둔 중국군 사령관, 극단적 폭력 행위를 절대 용납하지 않겠다 경고',
#  ' 통일농구 방북단 귀환 조명균 체육교류 계속 이어질 것',
#  ' 국립현대미술관, 미술과 민주주의 화두로 국제심포지엄 개최',
#  ' 지에스버그 교통 앱 위카오 택시',
#  ' 안전 위협하는 어린이보호구역 후진 차량 사고',
#  ' "베 린 하모 서 한 오케스트라, 평화의 염원 소리를 되찾다"',
#  ' 치안불안 아프리카 말리, 새 총리에 시세 전 재무장관 임명',
#  ' "카카오, 주당 2,000원 분기별 배당 결의" ',
#  ' 간편결제 위탁 모바일 결제 시스템 출시',
#  ' 네이버 모바일 첫 화면 검색창 위주 개편, 뉴스 실급검 뺀다',
#  ' 한파로 갯벌도 얼려버렸다',
#  ' 국제종 기 수 서 제출 - 한국 도시',
#  ' 한국 게이트 대구사회 모금회에 1억 원 기부',
#  ' 게시판 현 미술 전시회',
#  ' 대통(대통령) 연정(연정) 승인(승인) 콘테(콘테) 총(총리) 에(에) 정(정부) 구성(구성) 권(권한) 부여(',
#  ' 그픽 아파트 매물 가격지수 변동',
#  ' 급 대폭 증가, 려야 뒤 객 증가',
#  ' 특징주 삼성전자 6일 만에 약세 전환',
#  ' 스턴 잭, 레인키 우승 후 순위',
#  ' 전면 열렬 환치합 - 코로나19 신규 확진자 1천명 육박',
#  ' 북한 산 양, 갈라진 땅으로 인한 니의 피해',
#  ' 아이폰 원, 유플러스 공식 온라인몰에서 1,000원에 판매',
#  ' 원숭이 이 성  아니다, 경연이 관건입니다',
#  ' "감자 장수 김주찬 결투로 패퇴, 삼촌이 대신 출전하다"',
#  ' 삼성 갤럭시 덱스 지원, 최적화된 오피스 앱 출시',
#  ' 베어링운용 증시 기초여건 우호적 위험요건은 상존',
#  ' 김정은 당 대회 함경북도 황해도 선시 대표로 추',
#  ' 부마항쟁 단체, 후보에 항쟁의 명예를 세워달라',
#  ' 아시안게임 라오스 야구팀, 스리랑카에 패배 짧지만 강렬한 경기',
#  ' "틴 에이지 뉴 메 감독, 그의 새로운 영화 "틴 에이지"를 발표합니다." ',
#  ' 방송통신위원회의 정치 후견주의 극복하고 독립성 강화해야',
#  ' 중국, 비트코인 거래자에게 철퇴: 출국 금지, 국선 사기 소송',
#  ' 한국의 관광객들이 코로나19 이후 발포된 물 속 이용 가능 여부를 알려드립니다. ',
#  ' 이란 핵합의서 한발 빼 저농축 우라늄 저장한도 10일 뒤 넘겨',
#  ' 제 6회 국제주택도시금융포럼 개막',
#  ' 투표현장에서 권영진 대구시장이 신명여중에서 투표했다.',
#  ' 러시아의 키 시, 건축물 화',
#  ' 미안 강남 포스트 약물량 경쟁률 대결',
#  ' 미스터 셀프를 위한 프로 부 인물들 납 해',
#  ' 홍윤식 청문회 총선 관리 지방 재정 등 정책질의 집중',
#  ' 시리아의 축출 후, 수단 군부정권을 이끄는 아우르는',
#  ' 내일 날씨는 찬바람 쌩쌩 불고 맹추위 서울 영하 2도',
#  ' 전세 시장 급격한 증가 추이',
#  ' 전국 천여 어촌 마을 대역 인 망 구',
#  ' 북한, 제4차 핵실험 성공',
#  ' 뱅크 전 주 증시 신규 주가 영업 협약 중',
#  ' 군부가 축출한 바시르 수단 전 대통령, 교도소 수감',
#  ' 게시판: 유플러스, 3년 연속 지속가능경영 보고서 발간',
#  ' 홍준표, 황교안 전 대출자 선거권 없어... 전대출마 자격 논란',
#  ' 난해 은행 신용대 금리 자천 감소',
#  ' "추수감사절 연휴 무안타 시리즈, 타율 0.000" ',
#  ' 대령 지휘부 도원장 만 청 소통 강화종',
#  ' 코리아 레길 민간추진협의회, 일 출 식 개최',
#  ' 더위 식히는 장맛비 남부 제주도 밤에 대부분 그쳐',
#  ' 코스피 상승 출발, 장중 선 돌파',
#  ' 퍼스트레이 주 개 에 공',
#  " 게시판 '훈클럽신영기' 지원 금 수",
#  ' 국민의당 당무위, 당내 진통 해결을 위한 긴급 회의 진행',
#  ' 빈자리 드문 세종 국무회의장',
#  ' 천은사, 장로회 폐지 업무 종료',
#  ' "유튜브, 후반기 경기 생중계 콘텐츠 독점 제공"',
#  " 신간 '미니스커트 경제학' - 잘못된 미니스커트 경제학에 대한 논란",
#  ' 화웨이 스마트폰 부품의 약 70% 한미일 기업에 의존',
#  ' 미래부, 과학기술정책위원회 워크숍 개최',
#  ' 대통령 시릴, 부모님을 잃은 것처럼',
#  ' "프랑 어의 실종: 당신이 남긴 증오의 흔적" ',
#  ' 이재명 후보가 대국민 방송을 통해 유세를 진행합니다.',
#  ' 정선군, 전기 독이 많은 배를 배운다',
#  ' 경남 초등학생 10만명에게 세정제 등 위생 키트 제공 추진',
#  ' "사우디, 이란과 중동에서 역할 재정립" ',
#  ' 부 러닝 트 인 상 원 공식 표 보 대회',
#  ' 김정은의 여성 매체에 대한 싫어하는 이유 분석',
#  ' 민주당, 한국당 중점 법안 난항에 고심',
#  ' "용산사옥에서 11월까지 구족화 특별전시회 개최"',
#  ' 류현진이 변했다, 콜로라도전 앞두고 또 불펜 투구',
#  ' 오륙도 등대를 덮치는 거대한 파도',
#  ' 경북  개 시 군 호우특보 해제, 대부분 비 그쳐',
#  ' 싱텔, 텔레콤 싱가포르 통신사, 스포츠 산업과 협력',
#  ' 러시아, 정식 제안 온 면에 푸틴과 만날 것',
#  ' 중소기업이 일자리  만개 늘릴 때 대기업은  만개 줄였다',
#  ' 노조 주최 시간제 근로자 대회',
#  ' 이 기오 10만 명의 환자 치료',
#  ' 박원 교육부, 누리과정에 대한 소통을 강화할 것',
#  ' 이총 히 대 시 구 장 등에 소홀하지 않아야 합니다.                ',
#  ' 골프, 시상식 역시 결승 골 중 1골로 반승',
#  ' 추미애 검언유착 수사 피의사실 공표 혐의로 고발돼',
#  ' 대통령, 조센 멍한 역할해야 창업국 기대',
#  ' 제1회 한국문학상 수상자 발표, 기타 셔플 참가자 명단 발표',
#  ' "켈리와 두산 용찬, 차차 선발 대결을 벌입니다."',
#  ' 리  폭 상  연방 정부의 코로나19 대응',
#  ' 화가 감독과 지휘자 타지 영이 함께하는 러시아 교향곡 공연',
#  ' 한진그룹 세대교체 인사 조현아는 인사 명단서 빠져종합 보도',
#  ' 미국 배가 드컵 종전 서에 석 승 패로 감',
#  ' "데일리 공유 앱, 가입자 증가 속도"',
#  ' 인항 무열 화재, 가정 한 채가 불타버렸다.',
#  ' 정의당 울시당 선거 후보 출정식',
#  ' 러시아 자배구 코치, 리 듀 리 기 리머',
#  ' "코로나 19 백신 개발, 갈증 풀릴까? 기술이 답이다."',
#  ' 신간 의사의 거짓말 가짜 건강상식: 건강에 해로운 생활 습관',
#  ' 외국인들이 좋아하는 작품, 인기 있는 외국 영화들',
#  ' 정글에서 외출, 유명한 골프 선수가 놓쳤던 순간을 담은 영상이 공개되다',
#  ' 버 모 일에 음성 이미지 검증 기능 배치',
#  ' 회전 카메라 탑재한 갤럭시 S6 단독 출시, 가격 1,000 원',
#  ' 일 정상회의 북핵 무역 투자 경 협력 등  의료 협력',
#  ' 지소연, 아시아 여자 구 아시 컵 국가대표로 탁',
#  ' 민간 우주개발시대 연다, 달 착륙은 2024년 목표 종합',
#  ' 평양정상회담, 남북은 하나 됨',
#  ' 지방서 새누 당원 동참 촉구 이어져 일부는 참석 대',
#  ' 문 통령 힘을  한 화 변 평 스로  어야종합',
#  ' 간호사는 100명이 무릎 부상을 당했습니다. ',
#  ' 포틀랜드 워싱턴 꺾고, 서부 콘퍼런스 선두로 도약',
#  ' 고개 인 야 교 단 연설 통 사과',
#  ' 주택연금 개혁, 내년부터 월 수령액 줄어',
#  ' 김동욱 거제시장 개혁부터 야',
#  ' "와, 권 공세가 입 불변의 지키기에 실패했습니다."',
#  ' 코스피 외국인 개인 팔자에 하락 사흘만에 종합',
#  ' 광주전남본부 보유 토지 1만 5천  매각',
#  ' 동아시아 러시아 모태 와하비즘 확산 제의',
#  ' 대선 후의 지속적인 야권 연대 성사',
#  ' 실시간 사상재난 구조 시스템 도입으로 안전한 사회 구현',
#  ' 대위 혁신형 관리형 중진들의 의견 종합',
#  ' "새로운 갤럭시 S22 자인 메라에 매료, 갤럭시 S22 개통 이벤트"',
#  ' 골프존, 스크린골프 프랜차이즈 전환 시범 운영 매장 모집 ',
#  ' 셀럽 사상 최초의 메시 발리에 날씨가 좋다',
#  ' 프로야구팀, 일본 고치에서부터 마무리 훈련 시작',
#  ' "보고 들으며 즐기는 찾아가는 시문학 공연: 시를 사랑하는 여러분을 초대합니다!"',
#  ' 거제시, 월간 출입제한 동계 정비 기간 내일 재개방',
#  ' 미국 멕시코 월드컵 2026 개최 가능성',
#  ...]

# %%
# 유사도 계산 및 선택
threshold = 30
selected_sentences = []

for aug_sentence in tqdm(augmented_sentences):
    tokenized_query = tokenizer.tokenize(aug_sentence)
    scores = bm25.get_scores(tokenized_query)
    max_score = max(scores)

    if max_score < threshold:
        selected_sentences.append(aug_sentence)
        
# 선택된 문장들 추가
final_sentences = corpus + selected_sentences
# Out:
# 100%|██████████| 5514/5514 [00:40<00:00, 135.15it/s]

# %%
len(final_sentences)
# Out:
# 4121

# %%
## sentence list Dataframe으로 치환
data = {
    'ID': [f'ynat-v1_train_{i:05d}' for i in range(len(final_sentences))],
    'text': final_sentences,
    'target': [0] * len(final_sentences)
}

augmented_train_df = pd.DataFrame(data)
augmented_train_df
# Out:
#                        ID                                           text  \
# 0     ynat-v1_train_00000               정권이 파리 미사 참석에 이용기간 제한을 두고 분열을 보임
# 1     ynat-v1_train_00001                          찰 국 로한 회장이 맡은 주요 프로젝트
# 2     ynat-v1_train_00002                      김정은, 자주통일 새 열쇠를 잡고 나서야 한다
# 3     ynat-v1_train_00003                  갤노트8 주말 27만대 개통…시장은 불법 보조금 얼룩
# 4     ynat-v1_train_00004                          대선을 앞두고 감시 강화, 단발적 비해
# ...                   ...                                            ...
# 4116  ynat-v1_train_04116                     설 맞이 도심 속 겨울 축제, 워커힐에서 즐기다
# 4117  ynat-v1_train_04117           "인터넷은행 진출에 신중한 종합 은행, 분기 영업 이익에 힘입어"
# 4118  ynat-v1_train_04118          "북한의 핵 실험 가능성, 언제쯤 김정은의 도발 징후가 나타날까?"
# 4119  ynat-v1_train_04119   삼성, 올해 첫 대형 프로젝트 수주, 1조원 규모의 첨단 조선소 건설 계약 체결
# 4120  ynat-v1_train_04120                   갤럭시 부진에 삼성 스마트폰 영업이익, 분기별 주춤
#
#       target
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 4116       0
# 4117       0
# 4118       0
# 4119       0
# 4120       0
#
# [4121 rows x 3 columns]

# %%
model = AutoModelForSequenceClassification.from_pretrained("outputs/self_train_step1/checkpoint-350").to(DEVICE)
model.eval()

augmented_train_relabelled = augmented_train_df.copy()

for idx, sample in tqdm(augmented_train_df.iterrows(), total=len(augmented_train_df), desc="Evaluating"):
    target_id = sample['ID']
    
    inputs = tokenizer(sample['text'], return_tensors="pt").to(DEVICE)
    with torch.no_grad():
        logits = model(**inputs).logits
        pred = torch.argmax(torch.nn.Softmax(dim=1)(logits), dim=1).cpu().numpy()
        augmented_train_relabelled.loc[augmented_train_relabelled['ID'] == target_id, 'target'] = pred[0]

augmented_train_relabelled.to_csv(f'./data/Self_train/self_train_step3.csv', index=False)
# Out:
# Evaluating: 100%|██████████| 4121/4121 [01:32<00:00, 44.74it/s]

# %% [markdown]
# # Re-labelling 3

# %%
dataset_train, dataset_valid = train_test_split(augmented_train_relabelled, test_size=0.2, random_state=SEED)

class BERTDataset(Dataset):
    def __init__(self, data, tokenizer):
        input_texts = data['text']
        targets = data['target']
        self.inputs = []; self.labels = []
        for text, label in zip(input_texts, targets):
            tokenized_input = tokenizer(text, padding='max_length', truncation=True, return_tensors='pt')
            self.inputs.append(tokenized_input)
            self.labels.append(torch.tensor(label))

    def __getitem__(self, idx):
        return {
            'input_ids': self.inputs[idx]['input_ids'].squeeze(0),
            'attention_mask': self.inputs[idx]['attention_mask'].squeeze(0),
            'labels': self.labels[idx].squeeze(0)
        }

    def __len__(self):
        return len(self.labels)

data_train = BERTDataset(dataset_train, tokenizer)
data_valid = BERTDataset(dataset_valid, tokenizer)

data_collator = DataCollatorWithPadding(tokenizer=tokenizer)

f1 = evaluate.load('f1')
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    return f1.compute(predictions=predictions, references=labels, average='macro')

# %%
training_args = TrainingArguments(
    output_dir=OUTPUT_DIR+'/Self_train_step3',
    overwrite_output_dir=True,
    do_train=True,
    do_eval=True,
    do_predict=True,
    report_to="wandb",
    logging_strategy='steps',
    eval_strategy='steps',
    save_strategy='steps',
    logging_steps=100,
    eval_steps=50,
    save_steps=50,
    save_total_limit=2,
    learning_rate= 2e-05,
    adam_beta1 = 0.9,
    adam_beta2 = 0.999,
    adam_epsilon=1e-08,
    weight_decay=0.01,
    lr_scheduler_type='linear',
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    gradient_accumulation_steps=2,
    num_train_epochs=10,
    load_best_model_at_end=True,
    metric_for_best_model='eval_f1',
    greater_is_better=True,
    seed=SEED
)


trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=data_train,
    eval_dataset=data_valid,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)
# Out:
# Detected kernel version 5.4.0, which is below the recommended minimum of 5.5.0; this can cause the process to hang. It is recommended to upgrade the kernel to the minimum version or higher.

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='322' max='1030' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 322/1030 18:20 < 40:34, 0.29 it/s, Epoch 3.12/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>No log</td>
#       <td>0.324325</td>
#       <td>0.888161</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.861300</td>
#       <td>0.344093</td>
#       <td>0.889226</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.861300</td>
#       <td>0.425726</td>
#       <td>0.875974</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.395400</td>
#       <td>0.400101</td>
#       <td>0.886577</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.395400</td>
#       <td>0.630774</td>
#       <td>0.863286</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.234400</td>
#       <td>0.507961</td>
#       <td>0.884126</td>
#     </tr>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 trainer.train()
#
# File /opt/conda/lib/python3.10/site-packages/transformers/trainer.py:2122, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2120         hf_hub_utils.enable_progress_bars()
#    2121 else:
# -> 2122     return inner_training_loop(
#    2123         args=args,
#    2124         resume_from_checkpoint=resume_from_checkpoint,
#    2125         trial=trial,
#    2126         ignore_keys_for_eval=ignore_keys_for_eval,
#    2127     )
#
# File /opt/conda/lib/python3.10/site-packages/transformers/trainer.py:2474, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2471     self.control = self.callback_handler.on_step_begin(args, self.state, self.control)
#    2473 with self.accelerator.accumulate(model):
# -> 2474     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2476 if (
#    2477     args.logging_nan_inf_filter
#    2478     and not is_torch_xla_available()
#    2479     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2480 ):
#    2481     # if loss is nan or inf simply add the average of previous logged losses
#    2482     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File /opt/conda/lib/python3.10/site-packages/transformers/trainer.py:3606, in Trainer.training_step(***failed resolving arguments***)
#    3604 else:
#    3605     loss *= self.args.gradient_accumulation_steps
# -> 3606     self.accelerator.backward(loss, **kwargs)
#    3608 return loss.detach() / self.args.gradient_accumulation_steps
#
# File /opt/conda/lib/python3.10/site-packages/accelerate/accelerator.py:2241, in Accelerator.backward(self, loss, **kwargs)
#    2239     self.lomo_backward(loss, learning_rate)
#    2240 else:
# -> 2241     loss.backward(**kwargs)
#
# File /opt/conda/lib/python3.10/site-packages/torch/_tensor.py:492, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     482 if has_torch_function_unary(self):
#     483     return handle_torch_function(
#     484         Tensor.backward,
#     485         (self,),
#    (...)
#     490         inputs=inputs,
#     491     )
# --> 492 torch.autograd.backward(
#     493     self, gradient, retain_graph, create_graph, inputs=inputs
#     494 )
#
# File /opt/conda/lib/python3.10/site-packages/torch/autograd/__init__.py:251, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     246     retain_graph = create_graph
#     248 # The reason we repeat the same comment below is that
#     249 # some Python versions print out the first line of a multi-line function
#     250 # calls in the traceback and some print out the last line
# --> 251 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     252     tensors,
#     253     grad_tensors_,
#     254     retain_graph,
#     255     create_graph,
#     256     inputs,
#     257     allow_unreachable=True,
#     258     accumulate_grad=True,
#     259 )
#
# KeyboardInterrupt:
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.

# %%
model = AutoModelForSequenceClassification.from_pretrained("data/outputs/Self_train_step3/checkpoint-300").to(DEVICE)
tokenizer = AutoTokenizer.from_pretrained(model_name)
model.eval()

st3_df = pd.read_csv(DATA_DIR + '/Self_train/self_train_step3.csv')
st3_df.head()
# Out:
#                     ID                              text  target
# 0  ynat-v1_train_00000  정권이 파리 미사 참석에 이용기간 제한을 두고 분열을 보임       6
# 1  ynat-v1_train_00001             찰 국 로한 회장이 맡은 주요 프로젝트       5
# 2  ynat-v1_train_00002         김정은, 자주통일 새 열쇠를 잡고 나서야 한다       2
# 3  ynat-v1_train_00003     갤노트8 주말 27만대 개통…시장은 불법 보조금 얼룩       4
# 4  ynat-v1_train_00004             대선을 앞두고 감시 강화, 단발적 비해       2

# %%
st3_relabelled = st3_df.copy()

for idx, sample in tqdm(st3_df.iterrows(), total=len(st3_df), desc="Evaluating"):
    target_id = sample['ID']
    
    inputs = tokenizer(sample['text'], return_tensors="pt").to(DEVICE)
    with torch.no_grad():
        logits = model(**inputs).logits
        pred = torch.argmax(torch.nn.Softmax(dim=1)(logits), dim=1).cpu().numpy()
        st3_relabelled.loc[st3_relabelled['ID'] == target_id, 'target'] = pred[0]

st3_relabelled.to_csv(f'./data/Self_train/self_train_step4.csv', index=False)
# Out:
# Evaluating: 100%|██████████| 4121/4121 [01:29<00:00, 45.98it/s]
# 현재 셀 또는 이전 셀에서 코드를 실행하는 동안 Kernel이 충돌했습니다.
#
# 셀의 코드를 검토하여 가능한 오류 원인을 식별하세요.
#
# 자세한 내용을 보려면 <a href='https://aka.ms/vscodeJupyterKernelCrash'>여기</a>를 클릭하세요.
#
# 자세한 내용은 Jupyter <a href='command:jupyter.viewOutput'>로그</a>를 참조하세요.
